# %% [markdown]
# # Math
#
# ## 1 Connection of directed graphs
#
# - (Original version) kNN graphs: $i^t\rightarrow j^{t+1}$ if node $i$ is one of the $k$-nearest neighbors of $j$. *Note: asymmetric*
#
# - (Simplified version) line graph: $i^t\rightarrow i^{t+1}$ for each $i, t$. For a line graph, its regularized Laplacian matrix $\mathbf{L}^d_r=\begin{bmatrix} 0\\ -1 & 1\\ & -1 & 1\\ & &\ddots &\ddots\\& & &-1 & 1\end{bmatrix}$
#   $$
#   (\mathbf{L}^d_r\mathbf{x})_{i,t} = \left\{
#   \begin{aligned}
#   &0 , && t=0\\
#   &x_{i, t} - x_{i, t-1}, && t > 0
#   \end{aligned}
#   \right.,\quad ((\mathbf{L}^d_r)^\top\mathbf{x})_{i,t} = \left\{
#   \begin{aligned}
#   &-x_{i, t+1} , && t=0\\
#   &x_{i, t} - x_{i, t+1}, && 0<t < T-1\\
#   & x_{i, t}, && t=T-1
#   \end{aligned}
#   \right.
#   $$
#
#
# ## 2 GLR for fully-undirected graph
#
# Only change directed graph into undirected graph, denote the original undirected graph on $T$ time frames as $\mathbf{L}^u$,  denote undirected cross-time connection as $\mathbf{L}^n$.
#
# - Line graph, compute regularized version:
#   $$
#   \mathbf{L}^n = \begin{bmatrix}
#   1 & -\frac{1}{\sqrt{2}}\\
#   -\frac{1}{\sqrt{2}} & 1 & -\frac{1}{\sqrt{2}}\\
#   & -\frac{1}{\sqrt{2}} & 1 & \ddots\\
#   & &\ddots & \ddots &-\frac{1}{\sqrt{2}}\\
#   & & & -\frac{1}{\sqrt{2}} & 1
#   \end{bmatrix}, (\mathbf{L}^n\mathbf{x})_{i,t} = x_{i,t} - \frac{1}{\sqrt{2}}(x_{i, t+1} + x_{i, t-1})
#   $$
#
#
# - kNN graph, compute *unregularized* version:
#   $$
#   (\mathbf{Lx})_i = [(\mathbf{D} - \mathbf{W})\mathbf{x}]_i = d_ix_i - \sum_j w_{ij}x_j=\sum_{(i,j)\in\mathcal{E}}w_{ij}(x_i - x_j)
#   $$
#   for kNN graph, compute its father features and children features separately:
#   $$
#   (\mathbf{L}^u\mathbf{x})_{i,t} = \sum_k w_{k,i}^{t-1, t} (x_{i, t} - x_{k, t-1}) + \sum_j w_{i,j}^{t-1, t} (x_{i, t} - x_{j, t+1})
#   $$

# %%
# import
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np 
from utils import *
from ADMM import *

# %% [markdown]
# # 1 Load data
#
# 1. prediction: `x = data[0:24], y = data[0:12]`
# 2. difference: `dx[t] = x[t+1] - x[t]`
# 3. interpolation: `x = data[0:24], y = x * mask`. Mask rate 0.4, set to `NaN`

# %%
# dataset
data_dir = '../datasets/PEMS0X_data'
# TODO: change here
dataset = 'PEMS04'
data_folder = os.path.join(data_dir, dataset)
data_file = dataset + '.npz'
graph_csv = dataset + '.csv'
# data
traffic_dataset = TrafficDataset(data_folder, data_file, graph_csv)
print(f"data shape: {traffic_dataset.data.shape}, node number: {traffic_dataset.graph_info['n_nodes']}, edge number: {traffic_dataset.graph_info['n_edges']}")

# kNNs and graph construction
k = 4
nearest_nodes, nearest_dists = k_nearest_neighbors(traffic_dataset.graph_info['n_nodes'], traffic_dataset.graph_info['u_edges'], traffic_dataset.graph_info['u_dist'], k)
print(f'nearest nodes: {nearest_nodes.shape}, nearest_dists: {nearest_dists.shape}')

# mixed_graph_from_distance()

x, y = traffic_dataset.get_predict_data(0)
x, y = x.unsqueeze(0), y.unsqueeze(0)
print(f'recovering: x: {x.shape}, y: {y.shape}')

# difference in data
diff_x, diff_y = get_data_difference(x), get_data_difference(y)
print(f'difference: x: {diff_x.shape}, y: {diff_y.shape}')

# interpolation
interp_x, interp_y, mask = traffic_dataset.get_interpolated_data(0, 0.4)
interp_x, interp_y, mask = interp_x.unsqueeze(0), interp_y.unsqueeze(0), mask.unsqueeze(0)
print(f'interpolation: x: {interp_x.shape}, y: {interp_y.shape}, mask: {mask.shape}')
# Out:
# data shape: torch.Size([16992, 307, 1]), node number: 307, edge number: 340
# 307 nodes, 4 neighbors
# nearest nodes: torch.Size([307, 5]), nearest_dists: torch.Size([307, 5])
# recovering: x: torch.Size([1, 24, 307, 1]), y: torch.Size([1, 12, 307, 1])
# difference: x: torch.Size([1, 23, 307, 1]), y: torch.Size([1, 11, 307, 1])
# interpolation: x: torch.Size([1, 24, 307, 1]), y: torch.Size([1, 24, 307, 1]), mask: torch.Size([1, 24, 307, 1])

# %% [markdown]
# # 2 Regression
#
# Test regression result for neighbor of one node
# - prediction
# - difference
# - interpolation

# %%
# take node 0 as an example
knn = nearest_nodes[0].to(torch.long) # [0. 92, 117, 173, 243]
# prediction
x_data = x[:,:,knn]
y_data = y[:,:,knn]
diff_x_data = diff_x[:,:,knn]
diff_y_data = diff_y[:,:,knn]
interp_x_data = interp_x[:,:,knn]
interp_y_data = interp_y[:,:,knn]
mask_data = mask[:,:,knn]

# linear regression
lr_y = initial_guess(y_data, 12, 24)
print(lr_y.shape)
t = torch.arange(0, 24, 1)
colors = plt.cm.Set1(np.linspace(0, 1, 5))

plt.figure()
for i, color in enumerate(colors):
    plt.plot(t, x_data.squeeze()[:,i], color=color, label=f'node {knn[i]}')
    plt.plot(t[11:], lr_y.squeeze()[11:,i], color=color, linestyle='--', alpha=0.6)
# plt.legend([f'node {i}' for i in knn])
plt.legend()
plt.title('Linear Regression for Prediction Problem')
plt.show()

# interpolation
lr_interp_y = initial_interpolation(interp_y_data, mask_data)
print(lr_interp_y.shape)
plt.figure()
for i, color in enumerate(colors):
    plt.plot(t, x_data.squeeze()[:,i], color=color, label=f'node {knn[i]}')
    plt.plot(t, lr_interp_y.squeeze()[:,i], color=color, linestyle='--', alpha=0.6)
    mask_i = mask_data.squeeze()[:,i].bool()

    # x_mask_i = x_data.squeeze()[mask.squeeze()[:,i] == 1, i]
    plt.scatter(t[mask_i], x_data.squeeze()[:,i][mask_i], color=color, marker='x')
# plt.legend([f'node {i}' for i in knn])
plt.legend()
plt.title('Linear Interpolation for Prediction Problem')
plt.show()

# difference
lr_diff_y = initial_guess(diff_y_data, 11, 23)
# t = torch.arange(0, 23, 1)
plt.figure()
for i, color in enumerate(colors):
    # plt.plot(t, x_data.squeeze()[:,i], color=color, label=f'node {knn[i]}')
    # plt.plot(t[11:], cumsum_y.squeeze()[11:,i], color=color, linestyle='--', alpha=0.6)
    plt.plot(t[:-1], diff_x_data.squeeze()[:,i], color=color, label=f'node {knn[i]}')
    plt.plot(t[10:-1], lr_diff_y.squeeze()[10:,i], color=color, linestyle='--', alpha=0.6)

plt.legend()
plt.title('Linear Regression for Difference Problem')
plt.show()

plt.figure()

# sum up
cumsum_y = torch.cumsum(lr_diff_y, dim=1) + y_data[:,:1]
cumsum_y = torch.cat((y_data[:,0:1], cumsum_y), dim=1)
print(cumsum_y.shape)
for i, color in enumerate(colors):
    # plt.plot(t, x_data.squeeze()[:,i], color=color, label=f'node {knn[i]}')
    # plt.plot(t[11:], cumsum_y.squeeze()[11:,i], color=color, linestyle='--', alpha=0.6)
    plt.plot(t, x_data.squeeze()[:,i], color=color, label=f'node {knn[i]}')
    plt.plot(t, cumsum_y.squeeze()[:,i], color=color, linestyle='--', alpha=0.6)

plt.legend()
plt.title('Linear Regression for Difference Problem (cumsum)')
plt.show()
# Out:
# torch.Size([1, 24, 5, 1])
# Linear regression: w torch.Size([1, 5, 1]), b torch.Size([1, 5, 1])
# torch.Size([1, 24, 5, 1])
# torch.Size([1, 24, 5, 1])

# %% [markdown]
# # 3 ADMM algorithm
#
# different graph types:
# - undirected graph: kNN graph based on distance on each layer
# - directed graphs:
#     - kNN graphs
#     - line graphs
#
# different data types:
# - prediction
# - interpolation
# - difference
#
# ablation studies:
# - w/o DGTV
# - w/o DGLR
# - fully undirected graph

# %% [markdown]
# ## 3.1 Prediction problems
# - with directed graph as kNN graph
# - directed graph as line graph

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            )
x_pred = admm_block.combined_loop(y)
admm_block.plot_residual(descriptions='Prediction, kNN, Original', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, kNN, Original', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# Directed Graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 5])
# ADMM iters 0: x_CG_iters 14, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1696, 23.77, 371.1], dual_err = [1696, 23.76, 371.1]
# ADMM iters 1: x_CG_iters 20, zu_CG_iters 11, zd_CG_iters 16, pri_err = [71.06, 7.413, 78.64], dual_err = [276.7, 444.6, 1955]
# ADMM iters 2: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [205.2, 6.469, 30.17], dual_err = [763.6, 218.2, 890.5]
# ADMM iters 3: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 16, pri_err = [187.4, 5.224, 40.53], dual_err = [706.4, 162.1, 690.7]
# ADMM iters 4: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 16, pri_err = [157.9, 5.401, 43.33], dual_err = [614.6, 128.9, 590.6]
# ADMM iters 5: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [132.1, 5.337, 40.05], dual_err = [534.2, 105, 514.1]
# ADMM iters 6: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [110.9, 4.635, 34.57], dual_err = [467.1, 86.06, 451.1]
# ADMM iters 7: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [93.53, 4.167, 28.84], dual_err = [411.1, 71.6, 398.2]
# ADMM iters 8: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [79.31, 3.921, 23.7], dual_err = [364.1, 60.31, 353.8]
# ADMM iters 9: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [67.62, 3.896, 19.37], dual_err = [324.6, 50.97, 316.1]
# ADMM iters 10: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [57.98, 3.605, 15.79], dual_err = [291, 43.87, 284.1]
# ADMM iters 11: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [49.98, 3.208, 12.9], dual_err = [262.3, 38.03, 256.6]
# ADMM iters 12: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [43.31, 2.928, 10.67], dual_err = [237.7, 33.36, 233]
# ADMM iters 13: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [37.73, 2.534, 8.886], dual_err = [216.4, 29.65, 212.5]
# ADMM iters 14: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 14, pri_err = [33.03, 2.194, 7.487], dual_err = [198, 26.43, 194.7]
# ADMM iters 15: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 14, pri_err = [29.05, 2.387, 6.371], dual_err = [181.9, 23.82, 179.2]
# ADMM iters 16: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 14, pri_err = [25.66, 2.043, 5.469], dual_err = [167.9, 21.75, 165.5]
# ADMM iters 17: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [22.76, 2.097, 4.744], dual_err = [155.5, 19.78, 153.6]
# ADMM iters 18: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [20.27, 1.408, 4.159], dual_err = [144.7, 18.42, 143]
# ADMM iters 19: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [18.11, 1.717, 3.681], dual_err = [135, 16.87, 133.6]
# ADMM iters 20: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [16.23, 1.558, 3.292], dual_err = [126.5, 15.8, 125.2]
# ADMM iters 21: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [14.59, 1.367, 2.975], dual_err = [118.9, 14.81, 117.8]
# ADMM iters 22: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [13.15, 1.3, 2.711], dual_err = [112.1, 13.91, 111.2]
# ADMM iters 23: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [11.89, 1.507, 2.483], dual_err = [106, 13.06, 105.2]
# ADMM iters 24: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [10.77, 0.9957, 2.303], dual_err = [100.6, 12.5, 99.9]
# ADMM iters 25: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [9.787, 0.9734, 2.112], dual_err = [95.68, 11.76, 95.09]
# ADMM iters 26: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [8.909, 0.9388, 1.961], dual_err = [91.26, 11.19, 90.74]
# ADMM iters 27: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [8.129, 1.326, 1.833], dual_err = [87.25, 10.63, 86.8]
# ADMM iters 28: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [7.433, 1.169, 1.739], dual_err = [83.59, 10.25, 83.2]
# ADMM iters 29: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.811, 1.02, 1.655], dual_err = [80.27, 9.871, 79.93]
# ADMM iters 30: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.254, 1.117, 1.561], dual_err = [77.23, 9.46, 76.93]
# ADMM iters 31: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.756, 0.8619, 1.48], dual_err = [74.45, 9.114, 74.18]
# ADMM iters 32: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.308, 1.046, 1.403], dual_err = [71.88, 8.723, 71.65]
# ADMM iters 33: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.906, 1.189, 1.325], dual_err = [69.51, 8.455, 69.31]
# ADMM iters 34: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.544, 0.8395, 1.276], dual_err = [67.32, 8.265, 67.13]
# ADMM iters 35: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.218, 0.6909, 1.219], dual_err = [65.28, 7.944, 65.12]
# ADMM iters 36: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.923, 0.9155, 1.159], dual_err = [63.39, 7.631, 63.24]
# ADMM iters 37: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.658, 0.7512, 1.097], dual_err = [61.61, 7.482, 61.48]
# ADMM iters 38: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.417, 1.043, 1.047], dual_err = [59.95, 7.2, 59.83]
# ADMM iters 39: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.2, 0.9899, 1.01], dual_err = [58.38, 7.068, 58.28]
# ADMM iters 40: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.003, 1.024, 0.9929], dual_err = [56.9, 6.877, 56.81]
# ADMM iters 41: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.823, 0.6595, 0.9747], dual_err = [55.51, 6.785, 55.42]
# ADMM iters 42: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.66, 0.7482, 0.9279], dual_err = [54.2, 6.513, 54.12]
# ADMM iters 43: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.511, 0.8409, 0.8943], dual_err = [52.95, 6.361, 52.88]
# ADMM iters 44: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.376, 0.7966, 0.8682], dual_err = [51.76, 6.231, 51.69]
# ADMM iters 45: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.252, 0.7362, 0.8499], dual_err = [50.63, 6.108, 50.57]
# ADMM iters 46: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.138, 0.6474, 0.8316], dual_err = [49.55, 5.952, 49.49]
# ADMM iters 47: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.034, 0.7242, 0.8041], dual_err = [48.52, 5.798, 48.47]
# ADMM iters 48: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.938, 0.7803, 0.7884], dual_err = [47.53, 5.709, 47.48]
# ADMM iters 49: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.849, 0.6416, 0.7784], dual_err = [46.58, 5.616, 46.54]
# ADMM iters 50: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.766, 0.6568, 0.7543], dual_err = [45.67, 5.472, 45.63]
# ADMM iters 51: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.69, 0.6739, 0.7346], dual_err = [44.8, 5.357, 44.77]
# ADMM iters 52: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.619, 0.7844, 0.7134], dual_err = [43.96, 5.25, 43.93]
# ADMM iters 53: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.555, 0.8328, 0.7052], dual_err = [43.16, 5.173, 43.12]
# ADMM iters 54: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.494, 0.7576, 0.7043], dual_err = [42.38, 5.095, 42.34]
# ADMM iters 55: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.436, 0.4832, 0.6974], dual_err = [41.62, 5.028, 41.59]
# ADMM iters 56: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.381, 0.3633, 0.667], dual_err = [40.9, 4.903, 40.88]
# ADMM iters 57: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.33, 0.3993, 0.6301], dual_err = [40.2, 4.786, 40.18]
# ADMM iters 58: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.282, 0.4483, 0.6053], dual_err = [39.53, 4.697, 39.51]
# ADMM iters 59: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.238, 0.5788, 0.5869], dual_err = [38.88, 4.615, 38.85]
# ADMM iters 60: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.196, 0.5551, 0.5757], dual_err = [38.24, 4.553, 38.22]
# ADMM iters 61: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.156, 0.5348, 0.5682], dual_err = [37.63, 4.485, 37.61]
# ADMM iters 62: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.118, 0.5113, 0.5624], dual_err = [37.04, 4.415, 37.02]
# ADMM iters 63: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.082, 0.4972, 0.5558], dual_err = [36.46, 4.337, 36.44]
# ADMM iters 64: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.048, 0.6439, 0.5461], dual_err = [35.9, 4.258, 35.88]
# ADMM iters 65: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.017, 0.5524, 0.5461], dual_err = [35.36, 4.224, 35.34]
# ADMM iters 66: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9864, 0.5364, 0.5455], dual_err = [34.83, 4.165, 34.81]
# ADMM iters 67: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9566, 0.509, 0.5328], dual_err = [34.32, 4.088, 34.3]
# ADMM iters 68: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9284, 0.5287, 0.5257], dual_err = [33.82, 4.028, 33.81]
# ADMM iters 69: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9015, 0.6187, 0.5092], dual_err = [33.34, 3.947, 33.32]
# ADMM iters 70: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8761, 0.5973, 0.5054], dual_err = [32.86, 3.927, 32.85]
# ADMM iters 71: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8519, 0.6066, 0.5082], dual_err = [32.4, 3.88, 32.39]
# ADMM iters 72: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.829, 0.5144, 0.5129], dual_err = [31.96, 3.83, 31.94]
# ADMM iters 73: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8058, 0.5676, 0.5022], dual_err = [31.52, 3.754, 31.51]
# ADMM iters 74: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7837, 0.6144, 0.4862], dual_err = [31.1, 3.7, 31.09]
# ADMM iters 75: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7632, 0.5905, 0.4812], dual_err = [30.68, 3.671, 30.67]
# ADMM iters 76: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7426, 0.5679, 0.4712], dual_err = [30.28, 3.611, 30.27]
# ADMM iters 77: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7232, 0.5904, 0.464], dual_err = [29.89, 3.552, 29.88]
# ADMM iters 78: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7043, 0.7757, 0.4471], dual_err = [29.5, 3.479, 29.49]
# ADMM iters 79: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6887, 0.6993, 0.4436], dual_err = [29.13, 3.49, 29.12]
# ADMM iters 80: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6728, 0.5534, 0.4554], dual_err = [28.76, 3.471, 28.75]
# ADMM iters 81: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6549, 0.4257, 0.4519], dual_err = [28.4, 3.399, 28.4]
# ADMM iters 82: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6368, 0.4989, 0.431], dual_err = [28.06, 3.319, 28.05]
# ADMM iters 83: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6208, 0.5647, 0.4183], dual_err = [27.72, 3.29, 27.71]
# ADMM iters 84: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6069, 0.5245, 0.4203], dual_err = [27.38, 3.273, 27.38]
# ADMM iters 85: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5924, 0.5319, 0.4137], dual_err = [27.06, 3.223, 27.05]
# ADMM iters 86: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5788, 0.4746, 0.4149], dual_err = [26.74, 3.194, 26.74]
# ADMM iters 87: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5646, 0.4906, 0.4027], dual_err = [26.43, 3.141, 26.43]
# ADMM iters 88: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5511, 0.5171, 0.3918], dual_err = [26.13, 3.105, 26.12]
# ADMM iters 89: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5385, 0.5601, 0.3844], dual_err = [25.83, 3.063, 25.83]
# ADMM iters 90: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5262, 0.6121, 0.3758], dual_err = [25.54, 3.035, 25.53]
# ADMM iters 91: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5147, 0.5964, 0.3741], dual_err = [25.26, 3.013, 25.25]
# ADMM iters 92: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5035, 0.5386, 0.3749], dual_err = [24.98, 2.981, 24.97]
# ADMM iters 93: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4917, 0.5279, 0.3651], dual_err = [24.7, 2.937, 24.7]
# ADMM iters 94: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4807, 0.5331, 0.3566], dual_err = [24.44, 2.907, 24.43]
# ADMM iters 95: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4706, 0.526, 0.3532], dual_err = [24.18, 2.876, 24.17]
# ADMM iters 96: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4611, 0.489, 0.3534], dual_err = [23.92, 2.855, 23.91]
# ADMM iters 97: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4515, 0.4546, 0.3511], dual_err = [23.67, 2.827, 23.66]
# ADMM iters 98: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4421, 0.4172, 0.3466], dual_err = [23.42, 2.789, 23.42]
# ADMM iters 99: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4325, 0.4632, 0.3413], dual_err = [23.18, 2.753, 23.17]
# torch.Size([100, 3]) torch.Size([100, 3]) torch.Size([100, 1])
# c:\Users\qij21\Desktop\test\ADMM-demo\ADMM.py:531: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:210.)
#   dxps = torch.tensor([item.cpu().detach().numpy() for item in self.delta_x_per_step]) # in (L, 24)

# %%
admm_block.plot_x_per_step(show_list=range(12, 24), start_iters=10, log_y=True)
admm_block.plot_x_per_step(show_list=range(12, 24), start_iters=10, log_y=False)
# admm_block.plot_CG_params()

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init * 2
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=True
                            )
x_pred = admm_block.combined_loop(y)
admm_block.plot_residual(descriptions='Prediction, Line Graph, Original', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, Line Graph, Original', log_y=True)
# admm_block.plot_CG_params()
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 1])
# ADMM iters 0: x_CG_iters 14, zu_CG_iters 11, zd_CG_iters 21, pri_err = [1696, 23.75, 500], dual_err = [1696, 23.74, 500]
# ADMM iters 1: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 21, pri_err = [71.81, 7.806, 148], dual_err = [307.3, 413.6, 1978]
# ADMM iters 2: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 20, pri_err = [206.8, 6.73, 38.9], dual_err = [774.2, 253.3, 892]
# ADMM iters 3: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 21, pri_err = [188.4, 7.227, 63.39], dual_err = [713.2, 186.9, 691.8]
# ADMM iters 4: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 21, pri_err = [158.4, 6.609, 81.73], dual_err = [618.7, 137.7, 592.2]
# ADMM iters 5: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 21, pri_err = [132.2, 6.049, 81.92], dual_err = [536.5, 99.47, 515.8]
# ADMM iters 6: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 20, pri_err = [110.8, 4.608, 72.4], dual_err = [468.2, 71.52, 452.4]
# ADMM iters 7: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 20, pri_err = [93.39, 3.981, 59.08], dual_err = [411.6, 52.68, 399.2]
# ADMM iters 8: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 20, pri_err = [79.13, 3.619, 45.46], dual_err = [364.4, 40.56, 354.3]
# ADMM iters 9: x_CG_iters 17, zu_CG_iters 11, zd_CG_iters 20, pri_err = [67.42, 3.025, 33.34], dual_err = [324.6, 33.64, 316.4]
# ADMM iters 10: x_CG_iters 17, zu_CG_iters 11, zd_CG_iters 20, pri_err = [57.77, 2.489, 23.58], dual_err = [291, 29.73, 284.1]
# ADMM iters 11: x_CG_iters 17, zu_CG_iters 11, zd_CG_iters 20, pri_err = [49.76, 2.649, 16.33], dual_err = [262.2, 26.56, 256.5]
# ADMM iters 12: x_CG_iters 17, zu_CG_iters 11, zd_CG_iters 19, pri_err = [43.09, 2.203, 11.34], dual_err = [237.6, 24.59, 232.8]
# ADMM iters 13: x_CG_iters 17, zu_CG_iters 11, zd_CG_iters 19, pri_err = [37.5, 2.354, 8.304], dual_err = [216.3, 22.34, 212.4]
# ADMM iters 14: x_CG_iters 17, zu_CG_iters 11, zd_CG_iters 19, pri_err = [32.79, 2.134, 6.613], dual_err = [197.8, 20.74, 194.5]
# ADMM iters 15: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 19, pri_err = [28.81, 1.929, 5.674], dual_err = [181.8, 19.08, 179]
# ADMM iters 16: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 19, pri_err = [25.42, 1.851, 5.087], dual_err = [167.7, 17.63, 165.4]
# ADMM iters 17: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 19, pri_err = [22.52, 1.827, 4.626], dual_err = [155.4, 16.36, 153.4]
# ADMM iters 18: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 19, pri_err = [20.03, 1.641, 4.214], dual_err = [144.5, 15.37, 142.9]
# ADMM iters 19: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 19, pri_err = [17.87, 1.576, 3.817], dual_err = [134.9, 14.36, 133.5]
# ADMM iters 20: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 19, pri_err = [16, 1.376, 3.478], dual_err = [126.4, 13.51, 125.2]
# ADMM iters 21: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 19, pri_err = [14.37, 1.522, 3.17], dual_err = [118.8, 12.75, 117.8]
# ADMM iters 22: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [12.94, 1.575, 2.941], dual_err = [112.1, 12.08, 111.2]
# ADMM iters 23: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [11.68, 1.164, 2.751], dual_err = [106, 11.56, 105.3]
# ADMM iters 24: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [10.57, 1.28, 2.564], dual_err = [100.6, 10.88, 99.95]
# ADMM iters 25: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [9.591, 1.239, 2.418], dual_err = [95.73, 10.43, 95.16]
# ADMM iters 26: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [8.721, 1.203, 2.288], dual_err = [91.33, 10, 90.83]
# ADMM iters 27: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [7.949, 1.266, 2.156], dual_err = [87.34, 9.541, 86.91]
# ADMM iters 28: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [7.26, 1.179, 2.057], dual_err = [83.71, 9.194, 83.33]
# ADMM iters 29: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [6.645, 1.096, 1.975], dual_err = [80.4, 8.901, 80.08]
# ADMM iters 30: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [6.096, 1.006, 1.895], dual_err = [77.38, 8.528, 77.1]
# ADMM iters 31: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [5.605, 1.05, 1.799], dual_err = [74.61, 8.217, 74.36]
# ADMM iters 32: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [5.164, 0.9551, 1.723], dual_err = [72.05, 7.964, 71.83]
# ADMM iters 33: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [4.768, 0.9051, 1.648], dual_err = [69.69, 7.699, 69.5]
# ADMM iters 34: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [4.412, 0.8047, 1.576], dual_err = [67.5, 7.467, 67.33]
# ADMM iters 35: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [4.091, 0.947, 1.498], dual_err = [65.47, 7.216, 65.32]
# ADMM iters 36: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [3.803, 1.016, 1.426], dual_err = [63.57, 7.03, 63.44]
# ADMM iters 37: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [3.542, 1.208, 1.386], dual_err = [61.8, 6.822, 61.68]
# ADMM iters 38: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [3.306, 1.012, 1.382], dual_err = [60.13, 6.754, 60.02]
# ADMM iters 39: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [3.094, 0.7118, 1.359], dual_err = [58.56, 6.572, 58.46]
# ADMM iters 40: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [2.9, 0.8817, 1.301], dual_err = [57.09, 6.317, 57]
# ADMM iters 41: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [2.725, 0.8097, 1.236], dual_err = [55.69, 6.205, 55.61]
# ADMM iters 42: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 18, pri_err = [2.565, 0.7773, 1.203], dual_err = [54.37, 6.066, 54.3]
# ADMM iters 43: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 18, pri_err = [2.42, 0.6552, 1.167], dual_err = [53.11, 5.923, 53.05]
# ADMM iters 44: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 18, pri_err = [2.287, 0.6955, 1.128], dual_err = [51.92, 5.767, 51.86]
# ADMM iters 45: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 18, pri_err = [2.165, 0.7902, 1.091], dual_err = [50.78, 5.642, 50.73]
# ADMM iters 46: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 18, pri_err = [2.055, 0.8162, 1.077], dual_err = [49.69, 5.532, 49.64]
# ADMM iters 47: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.953, 0.8914, 1.08], dual_err = [48.65, 5.431, 48.61]
# ADMM iters 48: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.859, 0.7034, 1.077], dual_err = [47.66, 5.367, 47.61]
# ADMM iters 49: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.772, 0.7443, 1.05], dual_err = [46.7, 5.22, 46.66]
# ADMM iters 50: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.691, 0.801, 1.018], dual_err = [45.79, 5.117, 45.75]
# ADMM iters 51: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.617, 0.8056, 1.01], dual_err = [44.9, 5.037, 44.87]
# ADMM iters 52: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.549, 0.7519, 1.009], dual_err = [44.06, 4.958, 44.02]
# ADMM iters 53: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.484, 0.6679, 0.9973], dual_err = [43.24, 4.868, 43.21]
# ADMM iters 54: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.424, 0.632, 0.9805], dual_err = [42.46, 4.762, 42.43]
# ADMM iters 55: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.368, 0.7569, 0.9544], dual_err = [41.7, 4.655, 41.67]
# ADMM iters 56: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.316, 0.8034, 0.9322], dual_err = [40.96, 4.591, 40.94]
# ADMM iters 57: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.267, 0.6709, 0.9165], dual_err = [40.25, 4.543, 40.23]
# ADMM iters 58: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.219, 0.6606, 0.895], dual_err = [39.57, 4.448, 39.55]
# ADMM iters 59: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.175, 0.6561, 0.8635], dual_err = [38.91, 4.37, 38.89]
# ADMM iters 60: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.134, 0.7013, 0.8371], dual_err = [38.27, 4.28, 38.25]
# ADMM iters 61: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.096, 0.711, 0.8272], dual_err = [37.65, 4.228, 37.63]
# ADMM iters 62: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.06, 0.7048, 0.8129], dual_err = [37.04, 4.153, 37.03]
# ADMM iters 63: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [1.025, 0.6976, 0.8047], dual_err = [36.46, 4.104, 36.44]
# ADMM iters 64: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [0.9914, 0.7186, 0.7985], dual_err = [35.89, 4.022, 35.88]
# ADMM iters 65: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [0.9604, 0.7816, 0.7969], dual_err = [35.34, 3.978, 35.32]
# ADMM iters 66: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [0.9315, 0.6352, 0.7972], dual_err = [34.8, 3.955, 34.79]
# ADMM iters 67: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [0.9009, 0.6168, 0.7681], dual_err = [34.29, 3.849, 34.27]
# ADMM iters 68: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 18, pri_err = [0.873, 0.7065, 0.7417], dual_err = [33.78, 3.777, 33.77]
# ADMM iters 69: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.8472, 0.7764, 0.7168], dual_err = [33.29, 3.732, 33.28]
# ADMM iters 70: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.8229, 0.8016, 0.7036], dual_err = [32.81, 3.686, 32.8]
# ADMM iters 71: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.7996, 0.783, 0.7048], dual_err = [32.34, 3.649, 32.33]
# ADMM iters 72: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.7768, 0.7213, 0.7071], dual_err = [31.89, 3.591, 31.88]
# ADMM iters 73: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.7546, 0.6668, 0.6986], dual_err = [31.45, 3.547, 31.44]
# ADMM iters 74: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.7334, 0.6264, 0.688], dual_err = [31.02, 3.494, 31.01]
# ADMM iters 75: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.7131, 0.63, 0.6819], dual_err = [30.6, 3.441, 30.59]
# ADMM iters 76: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.6937, 0.6197, 0.6826], dual_err = [30.19, 3.409, 30.18]
# ADMM iters 77: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.6753, 0.5607, 0.6855], dual_err = [29.79, 3.37, 29.78]
# ADMM iters 78: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.6565, 0.5576, 0.6754], dual_err = [29.4, 3.313, 29.39]
# ADMM iters 79: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.639, 0.6106, 0.666], dual_err = [29.02, 3.258, 29.01]
# ADMM iters 80: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.6223, 0.6965, 0.6396], dual_err = [28.65, 3.212, 28.64]
# ADMM iters 81: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.6074, 0.7544, 0.6298], dual_err = [28.29, 3.182, 28.28]
# ADMM iters 82: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.5928, 0.8041, 0.6353], dual_err = [27.93, 3.154, 27.92]
# ADMM iters 83: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.5788, 0.733, 0.6415], dual_err = [27.58, 3.15, 27.57]
# ADMM iters 84: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.5644, 0.7234, 0.6456], dual_err = [27.24, 3.08, 27.24]
# ADMM iters 85: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.551, 0.6427, 0.6546], dual_err = [26.91, 3.064, 26.9]
# ADMM iters 86: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.5361, 0.6208, 0.6312], dual_err = [26.59, 3.002, 26.58]
# ADMM iters 87: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.5217, 0.6672, 0.5922], dual_err = [26.27, 2.949, 26.27]
# ADMM iters 88: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.5097, 0.62, 0.5798], dual_err = [25.96, 2.935, 25.95]
# ADMM iters 89: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.498, 0.5343, 0.5819], dual_err = [25.66, 2.905, 25.65]
# ADMM iters 90: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4849, 0.5561, 0.5673], dual_err = [25.36, 2.852, 25.36]
# ADMM iters 91: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4735, 0.5261, 0.5545], dual_err = [25.07, 2.826, 25.07]
# ADMM iters 92: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4622, 0.5059, 0.5404], dual_err = [24.79, 2.792, 24.78]
# ADMM iters 93: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4511, 0.5081, 0.5224], dual_err = [24.51, 2.752, 24.5]
# ADMM iters 94: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4409, 0.5141, 0.5128], dual_err = [24.24, 2.722, 24.23]
# ADMM iters 95: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4311, 0.5218, 0.5087], dual_err = [23.97, 2.693, 23.96]
# ADMM iters 96: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4217, 0.5349, 0.5115], dual_err = [23.71, 2.662, 23.7]
# ADMM iters 97: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4123, 0.5512, 0.5168], dual_err = [23.45, 2.64, 23.44]
# ADMM iters 98: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.4027, 0.5729, 0.5262], dual_err = [23.2, 2.613, 23.19]
# ADMM iters 99: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 17, pri_err = [0.3945, 0.5776, 0.5456], dual_err = [22.95, 2.604, 22.94]
# torch.Size([100, 3]) torch.Size([100, 3]) torch.Size([100, 1])

# %%
admm_block.plot_x_per_step(show_list=range(12, 24), start_iters=10, log_y=True)
admm_block.plot_x_per_step(show_list=range(12, 24), start_iters=10, log_y=False)

# %% [markdown]
# ## 3.2 Interpolation Problems
# - directed graphs as kNN graphs
# - directed graphs as line graphs

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            )
x_interp = admm_block.combined_loop(interp_y, mask=mask)
admm_block.plot_residual(descriptions='Interpolation, kNN, Original', log_y=True)
admm_block.plot_x_per_step(descriptions='Interpolation, kNN, Original', log_y=False)
admm_block.plot_x_per_step(descriptions='Interpolation, kNN, Original', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# Directed Graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 5])
# Linear regression: w torch.Size([1, 307, 1]), b torch.Size([1, 307, 1])
# ADMM iters 0: x_CG_iters 14, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1186, 23.21, 573.8], dual_err = [1187, 23.21, 573.8]
# ADMM iters 1: x_CG_iters 20, zu_CG_iters 11, zd_CG_iters 16, pri_err = [46.49, 8.889, 130.6], dual_err = [207.9, 575.8, 1317]
# ADMM iters 2: x_CG_iters 20, zu_CG_iters 11, zd_CG_iters 16, pri_err = [128.9, 7.394, 40.32], dual_err = [487.6, 313.1, 546.8]
# ADMM iters 3: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 16, pri_err = [113.1, 7.063, 67.99], dual_err = [432.7, 230.7, 410.3]
# ADMM iters 4: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 16, pri_err = [91.52, 7.222, 75.79], dual_err = [361.7, 180.5, 342.2]
# ADMM iters 5: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 16, pri_err = [73.63, 6.813, 71.21], dual_err = [302.7, 144.4, 289.9]
# ADMM iters 6: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [59.61, 6.336, 62.3], dual_err = [255.5, 117.2, 247]
# ADMM iters 7: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [48.65, 6.481, 52.7], dual_err = [217.7, 96.07, 211.7]
# ADMM iters 8: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [40.05, 5.93, 43.85], dual_err = [187, 79.84, 182.6]
# ADMM iters 9: x_CG_iters 19, zu_CG_iters 10, zd_CG_iters 15, pri_err = [33.25, 5.666, 36.32], dual_err = [162, 67.15, 158.6]
# ADMM iters 10: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [27.84, 4.398, 30.13], dual_err = [141.3, 57.4, 138.6]
# ADMM iters 11: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [23.5, 4.125, 25.2], dual_err = [124.1, 49.38, 121.9]
# ADMM iters 12: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [19.99, 3.915, 21.22], dual_err = [109.6, 42.96, 107.8]
# ADMM iters 13: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [17.12, 3.979, 18.03], dual_err = [97.26, 37.48, 95.78]
# ADMM iters 14: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [14.75, 3.148, 15.41], dual_err = [86.7, 33.38, 85.47]
# ADMM iters 15: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [12.79, 2.374, 13.32], dual_err = [77.65, 29.63, 76.62]
# ADMM iters 16: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [11.14, 2.203, 11.61], dual_err = [69.81, 26.38, 68.94]
# ADMM iters 17: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [9.754, 2.225, 10.17], dual_err = [62.95, 23.69, 62.23]
# ADMM iters 18: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [8.571, 2.033, 8.955], dual_err = [56.96, 21.32, 56.35]
# ADMM iters 19: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 14, pri_err = [7.56, 1.971, 7.918], dual_err = [51.68, 19.23, 51.17]
# ADMM iters 20: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.688, 2.005, 7.033], dual_err = [47.01, 17.41, 46.58]
# ADMM iters 21: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.933, 1.776, 6.267], dual_err = [42.88, 15.81, 42.51]
# ADMM iters 22: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.278, 1.591, 5.611], dual_err = [39.2, 14.4, 38.88]
# ADMM iters 23: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.707, 1.466, 5.027], dual_err = [35.92, 13.11, 35.66]
# ADMM iters 24: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.207, 0.9703, 4.521], dual_err = [32.99, 12.01, 32.77]
# ADMM iters 25: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.768, 0.7541, 4.085], dual_err = [30.37, 10.99, 30.18]
# ADMM iters 26: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.381, 0.7117, 3.7], dual_err = [28.02, 10.08, 27.85]
# ADMM iters 27: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.04, 0.7637, 3.359], dual_err = [25.9, 9.267, 25.76]
# ADMM iters 28: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.738, 0.8431, 3.056], dual_err = [23.98, 8.536, 23.86]
# ADMM iters 29: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.471, 0.8561, 2.787], dual_err = [22.24, 7.897, 22.14]
# ADMM iters 30: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.233, 0.6947, 2.552], dual_err = [20.67, 7.309, 20.58]
# ADMM iters 31: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.022, 0.6872, 2.34], dual_err = [19.24, 6.772, 19.16]
# ADMM iters 32: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.835, 0.6407, 2.149], dual_err = [17.93, 6.292, 17.87]
# ADMM iters 33: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.667, 0.419, 1.982], dual_err = [16.75, 5.866, 16.69]
# ADMM iters 34: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.517, 0.5102, 1.829], dual_err = [15.66, 5.436, 15.61]
# ADMM iters 35: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.383, 0.5534, 1.689], dual_err = [14.66, 5.073, 14.62]
# ADMM iters 36: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.264, 0.5031, 1.566], dual_err = [13.75, 4.751, 13.71]
# ADMM iters 37: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.155, 0.5269, 1.453], dual_err = [12.91, 4.427, 12.88]
# ADMM iters 38: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.058, 0.5066, 1.35], dual_err = [12.13, 4.153, 12.11]
# ADMM iters 39: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9715, 0.4401, 1.255], dual_err = [11.42, 3.894, 11.39]
# ADMM iters 40: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8929, 0.528, 1.169], dual_err = [10.75, 3.641, 10.74]
# ADMM iters 41: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8231, 0.4152, 1.095], dual_err = [10.14, 3.448, 10.12]
# ADMM iters 42: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7595, 0.3868, 1.028], dual_err = [9.57, 3.235, 9.557]
# ADMM iters 43: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7024, 0.2748, 0.9679], dual_err = [9.043, 3.056, 9.031]
# ADMM iters 44: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6498, 0.2216, 0.909], dual_err = [8.553, 2.877, 8.544]
# ADMM iters 45: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6019, 0.214, 0.8531], dual_err = [8.097, 2.712, 8.09]
# ADMM iters 46: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5588, 0.2069, 0.8026], dual_err = [7.672, 2.561, 7.666]
# ADMM iters 47: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5196, 0.2563, 0.7556], dual_err = [7.274, 2.421, 7.269]
# ADMM iters 48: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4842, 0.263, 0.7112], dual_err = [6.901, 2.295, 6.897]
# ADMM iters 49: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4521, 0.1844, 0.6717], dual_err = [6.553, 2.178, 6.549]
# ADMM iters 50: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.422, 0.177, 0.6341], dual_err = [6.226, 2.062, 6.223]
# ADMM iters 51: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3942, 0.197, 0.5985], dual_err = [5.92, 1.953, 5.917]
# ADMM iters 52: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3691, 0.2236, 0.5669], dual_err = [5.631, 1.853, 5.629]
# ADMM iters 53: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3461, 0.2446, 0.5369], dual_err = [5.36, 1.762, 5.358]
# ADMM iters 54: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3253, 0.2529, 0.5097], dual_err = [5.104, 1.673, 5.103]
# ADMM iters 55: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3061, 0.2525, 0.4844], dual_err = [4.863, 1.594, 4.862]
# ADMM iters 56: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2884, 0.2123, 0.4616], dual_err = [4.636, 1.519, 4.635]
# ADMM iters 57: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.272, 0.1697, 0.4399], dual_err = [4.421, 1.448, 4.421]
# ADMM iters 58: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2566, 0.1444, 0.4189], dual_err = [4.219, 1.377, 4.219]
# ADMM iters 59: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2423, 0.1312, 0.3985], dual_err = [4.027, 1.311, 4.027]
# ADMM iters 60: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.229, 0.1125, 0.3788], dual_err = [3.846, 1.25, 3.847]
# ADMM iters 61: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2165, 0.1096, 0.3598], dual_err = [3.676, 1.188, 3.676]
# ADMM iters 62: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2049, 0.1172, 0.3415], dual_err = [3.513, 1.134, 3.514]
# ADMM iters 63: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1942, 0.1036, 0.3249], dual_err = [3.36, 1.083, 3.36]
# ADMM iters 64: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1842, 0.08529, 0.31], dual_err = [3.214, 1.034, 3.215]
# ADMM iters 65: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1747, 0.08252, 0.2956], dual_err = [3.076, 0.9861, 3.077]
# ADMM iters 66: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1658, 0.08654, 0.2818], dual_err = [2.945, 0.942, 2.946]
# ADMM iters 67: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1576, 0.08077, 0.2691], dual_err = [2.821, 0.9005, 2.821]
# ADMM iters 68: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1499, 0.07879, 0.2573], dual_err = [2.702, 0.8583, 2.703]
# ADMM iters 69: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1427, 0.1139, 0.2451], dual_err = [2.589, 0.8188, 2.59]
# ADMM iters 70: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1363, 0.1183, 0.2324], dual_err = [2.482, 0.7833, 2.482]
# ADMM iters 71: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1304, 0.1019, 0.2215], dual_err = [2.379, 0.7497, 2.38]
# ADMM iters 72: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1246, 0.08115, 0.212], dual_err = [2.282, 0.7176, 2.283]
# ADMM iters 73: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1189, 0.06504, 0.2031], dual_err = [2.189, 0.6873, 2.19]
# ADMM iters 74: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1133, 0.0551, 0.1945], dual_err = [2.101, 0.6584, 2.101]
# ADMM iters 75: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1081, 0.04969, 0.1863], dual_err = [2.017, 0.6308, 2.017]
# ADMM iters 76: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1031, 0.047, 0.1785], dual_err = [1.936, 0.6046, 1.937]
# ADMM iters 77: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09839, 0.04611, 0.171], dual_err = [1.86, 0.5797, 1.86]
# ADMM iters 78: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09397, 0.04737, 0.1639], dual_err = [1.787, 0.5554, 1.787]
# ADMM iters 79: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08982, 0.04909, 0.1571], dual_err = [1.717, 0.533, 1.717]
# ADMM iters 80: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0858, 0.04764, 0.1506], dual_err = [1.65, 0.5117, 1.651]
# ADMM iters 81: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08203, 0.04088, 0.1447], dual_err = [1.587, 0.4914, 1.587]
# ADMM iters 82: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07844, 0.03448, 0.1391], dual_err = [1.526, 0.4719, 1.526]
# ADMM iters 83: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.075, 0.02928, 0.1337], dual_err = [1.468, 0.4532, 1.468]
# ADMM iters 84: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0717, 0.02546, 0.1285], dual_err = [1.413, 0.4356, 1.413]
# ADMM iters 85: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06851, 0.02402, 0.1234], dual_err = [1.36, 0.4185, 1.36]
# ADMM iters 86: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06555, 0.02271, 0.1187], dual_err = [1.309, 0.4024, 1.309]
# ADMM iters 87: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06275, 0.02195, 0.1142], dual_err = [1.26, 0.3871, 1.261]
# ADMM iters 88: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06011, 0.02129, 0.1099], dual_err = [1.214, 0.3724, 1.214]
# ADMM iters 89: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0576, 0.02058, 0.1059], dual_err = [1.17, 0.3584, 1.17]
# ADMM iters 90: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05523, 0.01918, 0.102], dual_err = [1.127, 0.345, 1.127]
# ADMM iters 91: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05296, 0.01845, 0.09815], dual_err = [1.086, 0.332, 1.087]
# ADMM iters 92: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05081, 0.01771, 0.09453], dual_err = [1.047, 0.3197, 1.047]
# ADMM iters 93: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04876, 0.01697, 0.09106], dual_err = [1.01, 0.3079, 1.01]
# ADMM iters 94: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04681, 0.01616, 0.08774], dual_err = [0.9736, 0.2966, 0.974]
# ADMM iters 95: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04495, 0.01547, 0.08454], dual_err = [0.9392, 0.2858, 0.9395]
# ADMM iters 96: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04317, 0.01481, 0.08149], dual_err = [0.9061, 0.2754, 0.9064]
# ADMM iters 97: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04148, 0.0142, 0.07856], dual_err = [0.8743, 0.2655, 0.8747]
# ADMM iters 98: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03986, 0.01311, 0.07574], dual_err = [0.8438, 0.2559, 0.8442]
# ADMM iters 99: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03831, 0.01222, 0.07302], dual_err = [0.8146, 0.2468, 0.8149]
# torch.Size([100, 3]) torch.Size([100, 3]) torch.Size([100, 1])

# %%
# line graph
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=True
                            )
x_interp = admm_block.combined_loop(interp_y, mask=mask)
admm_block.plot_residual(descriptions='Interpolation, Line Graph, Original', log_y=True)
admm_block.plot_x_per_step(descriptions='Interpolation, Line Graph, Original', log_y=False)
admm_block.plot_x_per_step(descriptions='Interpolation, Line Graph, Original', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 1])
# Linear regression: w torch.Size([1, 307, 1]), b torch.Size([1, 307, 1])
# ADMM iters 0: x_CG_iters 14, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1186, 23.18, 573.2], dual_err = [1187, 23.18, 573.2]
# ADMM iters 1: x_CG_iters 20, zu_CG_iters 11, zd_CG_iters 16, pri_err = [44.05, 9.087, 132.9], dual_err = [202.9, 544.4, 1337]
# ADMM iters 2: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [129, 7.469, 37.47], dual_err = [487.8, 311.2, 545.5]
# ADMM iters 3: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 16, pri_err = [113.1, 7.422, 68.75], dual_err = [432.7, 229.9, 408.7]
# ADMM iters 4: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 16, pri_err = [91.44, 7.435, 77.52], dual_err = [361.5, 179.6, 341.4]
# ADMM iters 5: x_CG_iters 19, zu_CG_iters 11, zd_CG_iters 15, pri_err = [73.53, 6.748, 73.03], dual_err = [302.4, 143.5, 289.4]
# ADMM iters 6: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [59.51, 6.263, 63.9], dual_err = [255.3, 116.2, 246.7]
# ADMM iters 7: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [48.56, 6.496, 54], dual_err = [217.5, 95.03, 211.4]
# ADMM iters 8: x_CG_iters 18, zu_CG_iters 11, zd_CG_iters 15, pri_err = [39.97, 6.23, 44.83], dual_err = [186.8, 78.85, 182.4]
# ADMM iters 9: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [33.18, 5.594, 37], dual_err = [161.8, 66.48, 158.4]
# ADMM iters 10: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [27.78, 4.434, 30.65], dual_err = [141.1, 56.67, 138.4]
# ADMM iters 11: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [23.45, 4.196, 25.56], dual_err = [123.9, 48.86, 121.7]
# ADMM iters 12: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [19.95, 3.797, 21.48], dual_err = [109.5, 42.51, 107.7]
# ADMM iters 13: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [17.09, 4.054, 18.21], dual_err = [97.16, 37.06, 95.68]
# ADMM iters 14: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [14.72, 2.998, 15.52], dual_err = [86.61, 33.09, 85.38]
# ADMM iters 15: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [12.77, 2.194, 13.41], dual_err = [77.57, 29.38, 76.53]
# ADMM iters 16: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [11.13, 2.345, 11.67], dual_err = [69.74, 26.13, 68.87]
# ADMM iters 17: x_CG_iters 18, zu_CG_iters 10, zd_CG_iters 15, pri_err = [9.738, 2.153, 10.21], dual_err = [62.88, 23.51, 62.16]
# ADMM iters 18: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 15, pri_err = [8.559, 2.055, 8.981], dual_err = [56.89, 21.14, 56.29]
# ADMM iters 19: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [7.548, 1.973, 7.935], dual_err = [51.62, 19.12, 51.1]
# ADMM iters 20: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.678, 1.885, 7.046], dual_err = [46.96, 17.31, 46.52]
# ADMM iters 21: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.927, 1.587, 6.28], dual_err = [42.83, 15.73, 42.46]
# ADMM iters 22: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.274, 1.603, 5.619], dual_err = [39.16, 14.29, 38.84]
# ADMM iters 23: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.702, 1.4, 5.029], dual_err = [35.88, 13.04, 35.61]
# ADMM iters 24: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.203, 0.9479, 4.526], dual_err = [32.95, 11.96, 32.72]
# ADMM iters 25: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.764, 0.7248, 4.091], dual_err = [30.33, 10.94, 30.14]
# ADMM iters 26: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.378, 0.7057, 3.705], dual_err = [27.98, 10.03, 27.81]
# ADMM iters 27: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.037, 0.732, 3.363], dual_err = [25.86, 9.227, 25.72]
# ADMM iters 28: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.736, 0.8592, 3.06], dual_err = [23.94, 8.501, 23.82]
# ADMM iters 29: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.468, 0.7755, 2.791], dual_err = [22.21, 7.868, 22.1]
# ADMM iters 30: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.231, 0.6416, 2.555], dual_err = [20.64, 7.276, 20.55]
# ADMM iters 31: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.021, 0.6484, 2.342], dual_err = [19.21, 6.733, 19.13]
# ADMM iters 32: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.833, 0.6364, 2.151], dual_err = [17.9, 6.262, 17.84]
# ADMM iters 33: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.666, 0.465, 1.984], dual_err = [16.72, 5.835, 16.66]
# ADMM iters 34: x_CG_iters 17, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.516, 0.5559, 1.834], dual_err = [15.63, 5.411, 15.58]
# ADMM iters 35: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.382, 0.5662, 1.695], dual_err = [14.63, 5.054, 14.59]
# ADMM iters 36: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.263, 0.5631, 1.572], dual_err = [13.72, 4.729, 13.69]
# ADMM iters 37: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.155, 0.5453, 1.461], dual_err = [12.88, 4.409, 12.85]
# ADMM iters 38: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.057, 0.4885, 1.357], dual_err = [12.1, 4.137, 12.08]
# ADMM iters 39: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9706, 0.434, 1.261], dual_err = [11.39, 3.873, 11.37]
# ADMM iters 40: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.892, 0.5035, 1.175], dual_err = [10.73, 3.623, 10.71]
# ADMM iters 41: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8221, 0.399, 1.1], dual_err = [10.12, 3.43, 10.1]
# ADMM iters 42: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7584, 0.3907, 1.032], dual_err = [9.548, 3.217, 9.534]
# ADMM iters 43: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7014, 0.2819, 0.972], dual_err = [9.021, 3.04, 9.01]
# ADMM iters 44: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6488, 0.2297, 0.9131], dual_err = [8.533, 2.861, 8.523]
# ADMM iters 45: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.601, 0.2221, 0.8573], dual_err = [8.078, 2.697, 8.07]
# ADMM iters 46: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5579, 0.2117, 0.8066], dual_err = [7.653, 2.547, 7.647]
# ADMM iters 47: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5187, 0.2596, 0.7595], dual_err = [7.256, 2.407, 7.251]
# ADMM iters 48: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4833, 0.2662, 0.7153], dual_err = [6.884, 2.282, 6.88]
# ADMM iters 49: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4512, 0.1905, 0.6756], dual_err = [6.536, 2.165, 6.532]
# ADMM iters 50: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4213, 0.1785, 0.6378], dual_err = [6.21, 2.051, 6.207]
# ADMM iters 51: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3935, 0.1989, 0.6019], dual_err = [5.904, 1.941, 5.902]
# ADMM iters 52: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3685, 0.2237, 0.5702], dual_err = [5.617, 1.843, 5.615]
# ADMM iters 53: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3456, 0.2318, 0.5406], dual_err = [5.346, 1.753, 5.344]
# ADMM iters 54: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3247, 0.2467, 0.5134], dual_err = [5.091, 1.664, 5.09]
# ADMM iters 55: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3054, 0.2411, 0.4876], dual_err = [4.851, 1.586, 4.85]
# ADMM iters 56: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2878, 0.1931, 0.4644], dual_err = [4.624, 1.512, 4.624]
# ADMM iters 57: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2713, 0.1439, 0.4425], dual_err = [4.411, 1.439, 4.41]
# ADMM iters 58: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2559, 0.1277, 0.4212], dual_err = [4.209, 1.369, 4.209]
# ADMM iters 59: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2417, 0.1046, 0.4008], dual_err = [4.018, 1.305, 4.019]
# ADMM iters 60: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2283, 0.0874, 0.3808], dual_err = [3.838, 1.242, 3.839]
# ADMM iters 61: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2159, 0.1084, 0.3616], dual_err = [3.668, 1.182, 3.669]
# ADMM iters 62: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2044, 0.1099, 0.3429], dual_err = [3.507, 1.128, 3.507]
# ADMM iters 63: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1938, 0.09019, 0.3264], dual_err = [3.354, 1.077, 3.354]
# ADMM iters 64: x_CG_iters 16, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1838, 0.0689, 0.3113], dual_err = [3.209, 1.028, 3.21]
# ADMM iters 65: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1743, 0.06583, 0.2967], dual_err = [3.072, 0.9803, 3.072]
# ADMM iters 66: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1655, 0.07844, 0.2828], dual_err = [2.941, 0.9366, 2.942]
# ADMM iters 67: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1573, 0.0761, 0.27], dual_err = [2.817, 0.8958, 2.818]
# ADMM iters 68: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1497, 0.06563, 0.2583], dual_err = [2.699, 0.8569, 2.7]
# ADMM iters 69: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1425, 0.05528, 0.2472], dual_err = [2.587, 0.8197, 2.588]
# ADMM iters 70: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1356, 0.046, 0.2364], dual_err = [2.481, 0.7845, 2.481]
# ADMM iters 71: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1292, 0.04194, 0.2261], dual_err = [2.379, 0.7508, 2.38]
# ADMM iters 72: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1231, 0.03947, 0.2163], dual_err = [2.283, 0.719, 2.283]
# ADMM iters 73: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1174, 0.03779, 0.2071], dual_err = [2.191, 0.6888, 2.191]
# ADMM iters 74: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.112, 0.03637, 0.1983], dual_err = [2.103, 0.6601, 2.104]
# ADMM iters 75: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1069, 0.03554, 0.19], dual_err = [2.019, 0.6327, 2.02]
# ADMM iters 76: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1021, 0.03489, 0.1821], dual_err = [1.94, 0.6066, 1.94]
# ADMM iters 77: x_CG_iters 15, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09753, 0.04643, 0.1746], dual_err = [1.863, 0.581, 1.864]
# ADMM iters 78: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.09328, 0.04926, 0.1672], dual_err = [1.791, 0.5576, 1.791]
# ADMM iters 79: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08929, 0.0442, 0.1603], dual_err = [1.721, 0.5351, 1.722]
# ADMM iters 80: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08547, 0.03729, 0.1539], dual_err = [1.655, 0.5137, 1.655]
# ADMM iters 81: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0818, 0.03191, 0.1478], dual_err = [1.591, 0.4931, 1.592]
# ADMM iters 82: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07828, 0.02592, 0.1419], dual_err = [1.531, 0.4736, 1.531]
# ADMM iters 83: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07483, 0.024, 0.1361], dual_err = [1.473, 0.4546, 1.473]
# ADMM iters 84: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0716, 0.02285, 0.1306], dual_err = [1.418, 0.4368, 1.418]
# ADMM iters 85: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06857, 0.02158, 0.1255], dual_err = [1.365, 0.4198, 1.365]
# ADMM iters 86: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06569, 0.04572, 0.1206], dual_err = [1.314, 0.4007, 1.314]
# ADMM iters 87: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06298, 0.05963, 0.1144], dual_err = [1.265, 0.3852, 1.265]
# ADMM iters 88: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06066, 0.05414, 0.1093], dual_err = [1.218, 0.3707, 1.219]
# ADMM iters 89: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0584, 0.04253, 0.1051], dual_err = [1.173, 0.3565, 1.174]
# ADMM iters 90: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0561, 0.03439, 0.1012], dual_err = [1.13, 0.3425, 1.131]
# ADMM iters 91: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05386, 0.03227, 0.09729], dual_err = [1.089, 0.3296, 1.09]
# ADMM iters 92: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05175, 0.02888, 0.09364], dual_err = [1.05, 0.3174, 1.05]
# ADMM iters 93: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04971, 0.02497, 0.09023], dual_err = [1.012, 0.3056, 1.012]
# ADMM iters 94: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04773, 0.02221, 0.08693], dual_err = [0.9758, 0.2942, 0.9762]
# ADMM iters 95: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04582, 0.02077, 0.08371], dual_err = [0.9411, 0.2833, 0.9415]
# ADMM iters 96: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04399, 0.01931, 0.08058], dual_err = [0.9079, 0.2729, 0.9082]
# ADMM iters 97: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04222, 0.01951, 0.0775], dual_err = [0.8759, 0.2627, 0.8763]
# ADMM iters 98: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04056, 0.02068, 0.07455], dual_err = [0.8453, 0.2532, 0.8456]
# ADMM iters 99: x_CG_iters 15, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03898, 0.02, 0.07177], dual_err = [0.8158, 0.2441, 0.8161]
# torch.Size([100, 3]) torch.Size([100, 3]) torch.Size([100, 1])

# %% [markdown]
# ## 3.3 Ablation Studies
#
# ### 3.3.1 Undirected graphs
# - with **line graph**
# - with **kNN graph**

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=True,
                            ablation='UT'
                            )
x_interp = admm_block.combined_loop(interp_y, mask=mask)
admm_block.plot_residual(descriptions='Interpolation, Line Graph, Undirected', log_y=True)
admm_block.plot_x_per_step(descriptions='Interpolation, Line Graph, Undirected', log_y=False)
admm_block.plot_x_per_step(descriptions='Interpolation, Line Graph, Undirected', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 1])
# Linear regression: w torch.Size([1, 307, 1]), b torch.Size([1, 307, 1])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1186, 573.2], dual_err = [1187, 573.2]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [92.63, 72.16], dual_err = [418, 1336]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [131.2, 92.99], dual_err = [504, 554]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [111.7, 90.53], dual_err = [430, 414.4]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [89.68, 72.53], dual_err = [355.8, 341.5]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [72.11, 54.53], dual_err = [297.6, 286.5]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [58.47, 40.82], dual_err = [251.8, 243.1]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [47.84, 31.39], dual_err = [215.2, 208.2]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [39.47, 25.07], dual_err = [185.5, 179.9]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [32.84, 20.7], dual_err = [161, 156.6]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [27.53, 17.5], dual_err = [140.7, 137.1]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [23.25, 15.01], dual_err = [123.6, 120.8]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [19.77, 13], dual_err = [109.2, 106.9]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [16.92, 11.33], dual_err = [96.85, 94.99]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [14.56, 9.928], dual_err = [86.27, 84.75]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [12.6, 8.735], dual_err = [77.14, 75.89]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [10.95, 7.716], dual_err = [69.22, 68.18]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [9.564, 6.841], dual_err = [62.31, 61.45]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [8.382, 6.088], dual_err = [56.26, 55.54]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [7.371, 5.436], dual_err = [50.95, 50.34]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.503, 4.871], dual_err = [46.26, 45.74]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.753, 4.379], dual_err = [42.11, 41.67]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.102, 3.949], dual_err = [38.43, 38.06]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.537, 3.573], dual_err = [35.15, 34.84]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.043, 3.241], dual_err = [32.23, 31.96]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.61, 2.949], dual_err = [29.61, 29.39]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.23, 2.691], dual_err = [27.27, 27.08]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.896, 2.461], dual_err = [25.16, 25]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.602, 2.257], dual_err = [23.27, 23.13]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.342, 2.075], dual_err = [21.55, 21.43]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.111, 1.912], dual_err = [20, 19.9]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.907, 1.765], dual_err = [18.6, 18.51]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.726, 1.633], dual_err = [17.32, 17.24]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.565, 1.514], dual_err = [16.15, 16.09]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.421, 1.407], dual_err = [15.09, 15.04]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.293, 1.309], dual_err = [14.12, 14.07]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.179, 1.22], dual_err = [13.23, 13.19]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.077, 1.139], dual_err = [12.41, 12.38]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.985, 1.065], dual_err = [11.66, 11.63]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9029, 0.9968], dual_err = [10.97, 10.94]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8292, 0.9346], dual_err = [10.33, 10.3]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7628, 0.8773], dual_err = [9.733, 9.716]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7031, 0.8245], dual_err = [9.185, 9.169]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6492, 0.7758], dual_err = [8.675, 8.662]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6004, 0.7307], dual_err = [8.202, 8.191]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5563, 0.689], dual_err = [7.761, 7.752]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5163, 0.6502], dual_err = [7.35, 7.342]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.48, 0.6142], dual_err = [6.966, 6.96]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.447, 0.5807], dual_err = [6.608, 6.602]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4168, 0.5495], dual_err = [6.272, 6.268]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3893, 0.5203], dual_err = [5.958, 5.954]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3642, 0.4931], dual_err = [5.663, 5.66]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3411, 0.4676], dual_err = [5.386, 5.383]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3199, 0.4437], dual_err = [5.126, 5.123]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3004, 0.4213], dual_err = [4.881, 4.879]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2825, 0.4003], dual_err = [4.65, 4.649]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2659, 0.3806], dual_err = [4.433, 4.431]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2506, 0.362], dual_err = [4.227, 4.226]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2365, 0.3446], dual_err = [4.034, 4.033]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2233, 0.3281], dual_err = [3.851, 3.85]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2111, 0.3126], dual_err = [3.678, 3.677]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1997, 0.298], dual_err = [3.514, 3.514]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1891, 0.2842], dual_err = [3.359, 3.359]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1793, 0.2711], dual_err = [3.212, 3.212]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.17, 0.2588], dual_err = [3.072, 3.072]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1614, 0.2471], dual_err = [2.94, 2.94]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1533, 0.2361], dual_err = [2.815, 2.815]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1457, 0.2256], dual_err = [2.696, 2.696]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1386, 0.2157], dual_err = [2.582, 2.583]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1319, 0.2063], dual_err = [2.475, 2.475]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1256, 0.1974], dual_err = [2.372, 2.373]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1197, 0.1889], dual_err = [2.275, 2.275]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1141, 0.1809], dual_err = [2.182, 2.183]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1088, 0.1733], dual_err = [2.094, 2.094]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1038, 0.166], dual_err = [2.01, 2.01]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09914, 0.1591], dual_err = [1.929, 1.93]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09468, 0.1525], dual_err = [1.853, 1.853]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.09047, 0.1463], dual_err = [1.78, 1.78]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08648, 0.1403], dual_err = [1.71, 1.711]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08269, 0.1347], dual_err = [1.644, 1.644]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07911, 0.1293], dual_err = [1.58, 1.58]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0757, 0.1241], dual_err = [1.519, 1.52]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07247, 0.1192], dual_err = [1.461, 1.462]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0694, 0.1145], dual_err = [1.406, 1.406]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06647, 0.1101], dual_err = [1.353, 1.353]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0637, 0.1058], dual_err = [1.302, 1.303]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06105, 0.1017], dual_err = [1.254, 1.254]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05854, 0.09782], dual_err = [1.207, 1.207]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05614, 0.0941], dual_err = [1.163, 1.163]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05386, 0.09054], dual_err = [1.12, 1.12]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05168, 0.08714], dual_err = [1.079, 1.079]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0496, 0.08389], dual_err = [1.04, 1.04]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04762, 0.08077], dual_err = [1.003, 1.003]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04573, 0.07779], dual_err = [0.9666, 0.9669]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04393, 0.07494], dual_err = [0.9321, 0.9323]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0422, 0.07221], dual_err = [0.899, 0.8992]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04056, 0.06959], dual_err = [0.8672, 0.8675]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03898, 0.06708], dual_err = [0.8368, 0.837]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03748, 0.06467], dual_err = [0.8075, 0.8077]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03604, 0.06237], dual_err = [0.7794, 0.7796]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=False,
                            ablation='UT'
                            )
x_interp = admm_block.combined_loop(interp_y, mask=mask)
admm_block.plot_residual(descriptions='Interpolation, kNN, Undirected', log_y=True)
admm_block.plot_x_per_step(descriptions='Interpolation, kNN, Undirected', log_y=False)
admm_block.plot_x_per_step(descriptions='Interpolation, kNN, Undirected', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# Directed Graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 5])
# Linear regression: w torch.Size([1, 307, 1]), b torch.Size([1, 307, 1])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1186, 573.8], dual_err = [1187, 573.8]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [94.81, 74.95], dual_err = [422.5, 1325]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [131.4, 91.79], dual_err = [504.7, 555.1]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [111.8, 89.27], dual_err = [430.3, 415.4]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [89.67, 71.68], dual_err = [355.9, 341.8]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [72.01, 54.07], dual_err = [297.5, 286.6]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [58.33, 40.61], dual_err = [251.6, 243]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [47.68, 31.32], dual_err = [215, 208.1]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [39.32, 25.06], dual_err = [185.3, 179.8]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [32.69, 20.71], dual_err = [160.8, 156.5]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [27.4, 17.5], dual_err = [140.5, 137]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [23.14, 15.02], dual_err = [123.5, 120.7]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [19.68, 13], dual_err = [109.1, 106.8]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [16.85, 11.33], dual_err = [96.77, 94.94]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [14.5, 9.921], dual_err = [86.22, 84.72]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [12.55, 8.726], dual_err = [77.11, 75.88]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [10.92, 7.707], dual_err = [69.2, 68.18]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [9.535, 6.832], dual_err = [62.3, 61.45]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [8.359, 6.078], dual_err = [56.26, 55.55]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [7.354, 5.427], dual_err = [50.95, 50.35]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.489, 4.862], dual_err = [46.27, 45.76]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.742, 4.371], dual_err = [42.12, 41.69]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.094, 3.941], dual_err = [38.44, 38.07]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.53, 3.565], dual_err = [35.16, 34.85]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.038, 3.234], dual_err = [32.24, 31.98]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.607, 2.943], dual_err = [29.63, 29.4]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.228, 2.684], dual_err = [27.29, 27.09]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.894, 2.455], dual_err = [25.18, 25.02]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.6, 2.251], dual_err = [23.28, 23.14]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.341, 2.069], dual_err = [21.57, 21.45]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.111, 1.907], dual_err = [20.02, 19.91]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.907, 1.76], dual_err = [18.61, 18.52]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.726, 1.629], dual_err = [17.33, 17.26]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.565, 1.51], dual_err = [16.17, 16.1]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.421, 1.402], dual_err = [15.1, 15.05]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.293, 1.305], dual_err = [14.13, 14.08]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.179, 1.216], dual_err = [13.24, 13.2]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.077, 1.135], dual_err = [12.42, 12.39]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9851, 1.061], dual_err = [11.67, 11.64]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.903, 0.9934], dual_err = [10.97, 10.95]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8292, 0.9313], dual_err = [10.33, 10.31]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7628, 0.8742], dual_err = [9.739, 9.722]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.703, 0.8215], dual_err = [9.19, 9.175]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6491, 0.773], dual_err = [8.68, 8.667]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6003, 0.728], dual_err = [8.206, 8.195]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5562, 0.6864], dual_err = [7.765, 7.755]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5161, 0.6478], dual_err = [7.353, 7.345]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4797, 0.6119], dual_err = [6.969, 6.963]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4466, 0.5785], dual_err = [6.61, 6.605]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4165, 0.5473], dual_err = [6.274, 6.269]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3889, 0.5183], dual_err = [5.959, 5.955]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3637, 0.4911], dual_err = [5.664, 5.661]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3406, 0.4657], dual_err = [5.387, 5.384]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3194, 0.4419], dual_err = [5.126, 5.124]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2999, 0.4196], dual_err = [4.881, 4.879]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2819, 0.3987], dual_err = [4.65, 4.648]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2653, 0.379], dual_err = [4.432, 4.431]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.25, 0.3605], dual_err = [4.227, 4.226]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2358, 0.3431], dual_err = [4.033, 4.032]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2226, 0.3267], dual_err = [3.849, 3.849]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2104, 0.3113], dual_err = [3.676, 3.676]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.199, 0.2967], dual_err = [3.512, 3.512]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1884, 0.283], dual_err = [3.357, 3.357]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1785, 0.27], dual_err = [3.21, 3.21]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1693, 0.2577], dual_err = [3.07, 3.07]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1607, 0.246], dual_err = [2.938, 2.938]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1526, 0.235], dual_err = [2.812, 2.812]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.145, 0.2246], dual_err = [2.693, 2.693]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1379, 0.2147], dual_err = [2.58, 2.58]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1312, 0.2054], dual_err = [2.472, 2.472]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1249, 0.1965], dual_err = [2.369, 2.37]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1189, 0.1881], dual_err = [2.272, 2.272]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1134, 0.1801], dual_err = [2.179, 2.179]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1081, 0.1725], dual_err = [2.091, 2.091]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1031, 0.1652], dual_err = [2.007, 2.007]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09841, 0.1584], dual_err = [1.926, 1.927]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09396, 0.1518], dual_err = [1.85, 1.85]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08976, 0.1456], dual_err = [1.777, 1.777]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08577, 0.1397], dual_err = [1.707, 1.707]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.082, 0.134], dual_err = [1.64, 1.641]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07842, 0.1286], dual_err = [1.577, 1.577]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07503, 0.1235], dual_err = [1.516, 1.517]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07181, 0.1186], dual_err = [1.458, 1.459]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06874, 0.114], dual_err = [1.403, 1.403]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06584, 0.1095], dual_err = [1.35, 1.35]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06307, 0.1053], dual_err = [1.299, 1.299]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06044, 0.1012], dual_err = [1.251, 1.251]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05794, 0.09733], dual_err = [1.204, 1.204]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05555, 0.09362], dual_err = [1.16, 1.16]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05328, 0.09008], dual_err = [1.117, 1.117]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05112, 0.08669], dual_err = [1.076, 1.077]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04905, 0.08345], dual_err = [1.037, 1.038]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04709, 0.08035], dual_err = [0.9997, 1]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04521, 0.07739], dual_err = [0.9638, 0.9641]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04342, 0.07455], dual_err = [0.9294, 0.9296]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0417, 0.07182], dual_err = [0.8963, 0.8966]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04007, 0.06922], dual_err = [0.8646, 0.8649]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03851, 0.06672], dual_err = [0.8342, 0.8345]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03702, 0.06433], dual_err = [0.805, 0.8052]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03559, 0.06203], dual_err = [0.777, 0.7772]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=True,
                            ablation='UT'
                            )
x_pred = admm_block.combined_loop(y)
admm_block.plot_residual(descriptions='Prediction, Line Graph, Undirected', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, Line Graph, Undirected', log_y=False)
admm_block.plot_x_per_step(descriptions='Prediction, Line Graph, Undirected', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 1])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1696, 345.9], dual_err = [1696, 345.9]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [80.61, 38.72], dual_err = [339.9, 1985]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [206.2, 49.86], dual_err = [768.9, 893.1]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [187.6, 48.68], dual_err = [707, 691.4]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [157.8, 38.45], dual_err = [614.2, 590.4]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [132, 28.03], dual_err = [533.7, 513.5]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [110.8, 20], dual_err = [466.7, 450.3]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [93.52, 14.48], dual_err = [410.9, 397.6]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [79.32, 10.89], dual_err = [364.1, 353.3]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [67.64, 8.575], dual_err = [324.5, 315.8]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [58, 7.047], dual_err = [291, 283.8]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [49.99, 5.98], dual_err = [262.3, 256.4]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [43.32, 5.188], dual_err = [237.7, 232.8]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [37.73, 4.571], dual_err = [216.4, 212.4]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [33.02, 4.071], dual_err = [198, 194.6]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [29.04, 3.656], dual_err = [181.9, 179.1]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [25.64, 3.306], dual_err = [167.8, 165.4]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [22.74, 3.006], dual_err = [155.5, 153.5]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [20.24, 2.747], dual_err = [144.6, 142.9]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [18.08, 2.521], dual_err = [134.9, 133.5]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [16.2, 2.324], dual_err = [126.4, 125.1]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [14.56, 2.151], dual_err = [118.8, 117.7]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [13.12, 1.997], dual_err = [112, 111.1]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [11.85, 1.861], dual_err = [105.9, 105.1]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [10.74, 1.74], dual_err = [100.5, 99.79]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [9.752, 1.632], dual_err = [95.57, 94.97]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.875, 1.535], dual_err = [91.14, 90.62]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.096, 1.448], dual_err = [87.13, 86.68]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [7.401, 1.369], dual_err = [83.49, 83.1]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.781, 1.298], dual_err = [80.17, 79.82]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.226, 1.233], dual_err = [77.13, 76.83]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.729, 1.174], dual_err = [74.35, 74.08]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.283, 1.12], dual_err = [71.78, 71.55]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.882, 1.07], dual_err = [69.41, 69.21]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.522, 1.024], dual_err = [67.22, 67.04]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.197, 0.9819], dual_err = [65.19, 65.02]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.905, 0.9428], dual_err = [63.29, 63.14]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.64, 0.9064], dual_err = [61.51, 61.38]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.401, 0.8726], dual_err = [59.85, 59.73]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.185, 0.841], dual_err = [58.28, 58.18]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.989, 0.8114], dual_err = [56.81, 56.72]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.811, 0.7837], dual_err = [55.42, 55.33]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.649, 0.7577], dual_err = [54.1, 54.02]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.501, 0.7332], dual_err = [52.85, 52.78]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.366, 0.7102], dual_err = [51.66, 51.6]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.242, 0.6884], dual_err = [50.53, 50.47]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.129, 0.6677], dual_err = [49.45, 49.39]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.025, 0.6482], dual_err = [48.41, 48.36]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.929, 0.6297], dual_err = [47.43, 47.38]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.841, 0.6121], dual_err = [46.48, 46.44]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.759, 0.5953], dual_err = [45.57, 45.53]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.684, 0.5794], dual_err = [44.7, 44.66]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.613, 0.5642], dual_err = [43.86, 43.82]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.548, 0.5498], dual_err = [43.05, 43.02]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.487, 0.5359], dual_err = [42.27, 42.24]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.43, 0.5227], dual_err = [41.52, 41.49]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.376, 0.5101], dual_err = [40.8, 40.77]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.326, 0.498], dual_err = [40.1, 40.07]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.279, 0.4864], dual_err = [39.42, 39.39]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.234, 0.4753], dual_err = [38.76, 38.74]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.192, 0.4646], dual_err = [38.13, 38.11]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.152, 0.4544], dual_err = [37.52, 37.5]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.115, 0.4446], dual_err = [36.92, 36.9]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.079, 0.4351], dual_err = [36.34, 36.33]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.045, 0.426], dual_err = [35.78, 35.77]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.013, 0.4173], dual_err = [35.24, 35.22]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.9818, 0.4088], dual_err = [34.71, 34.7]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.9524, 0.4007], dual_err = [34.2, 34.18]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.9244, 0.3929], dual_err = [33.7, 33.69]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8976, 0.3853], dual_err = [33.22, 33.2]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.872, 0.3781], dual_err = [32.75, 32.73]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8474, 0.371], dual_err = [32.29, 32.27]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8239, 0.3642], dual_err = [31.84, 31.83]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8013, 0.3577], dual_err = [31.41, 31.39]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7796, 0.3513], dual_err = [30.98, 30.97]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7587, 0.3452], dual_err = [30.57, 30.56]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7387, 0.3392], dual_err = [30.17, 30.16]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7194, 0.3335], dual_err = [29.77, 29.76]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7009, 0.3279], dual_err = [29.39, 29.38]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.683, 0.3225], dual_err = [29.02, 29.01]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6657, 0.3173], dual_err = [28.65, 28.64]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6491, 0.3122], dual_err = [28.3, 28.29]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6331, 0.3073], dual_err = [27.95, 27.94]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6176, 0.3025], dual_err = [27.61, 27.6]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6027, 0.2978], dual_err = [27.28, 27.27]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5882, 0.2933], dual_err = [26.95, 26.95]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5743, 0.2889], dual_err = [26.64, 26.63]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5608, 0.2847], dual_err = [26.33, 26.32]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5478, 0.2805], dual_err = [26.02, 26.02]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5351, 0.2765], dual_err = [25.72, 25.72]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5229, 0.2726], dual_err = [25.43, 25.43]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.5111, 0.2688], dual_err = [25.15, 25.14]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4997, 0.2651], dual_err = [24.87, 24.86]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4886, 0.2614], dual_err = [24.6, 24.59]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4779, 0.2579], dual_err = [24.33, 24.32]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4674, 0.2545], dual_err = [24.07, 24.06]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4574, 0.2511], dual_err = [23.81, 23.8]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4476, 0.2479], dual_err = [23.56, 23.55]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4381, 0.2447], dual_err = [23.31, 23.31]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4289, 0.2416], dual_err = [23.07, 23.06]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=False,
                            ablation='UT'
                            )
x_pred = admm_block.combined_loop(y)
admm_block.plot_residual(descriptions='Prediction, kNN, Undirected', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, kNN, Undirected', log_y=False)
admm_block.plot_x_per_step(descriptions='Prediction, kNN, Undirected', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# Directed Graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 5])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1696, 371.1], dual_err = [1696, 371.1]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [89.95, 51.7], dual_err = [361.2, 1970]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [207.3, 53.39], dual_err = [771.6, 894.9]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [187.7, 50.48], dual_err = [707.6, 692.6]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [157.7, 39.88], dual_err = [613.9, 590.6]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [131.7, 29.34], dual_err = [532.9, 513.1]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [110.3, 21.21], dual_err = [465.7, 449.6]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [92.96, 15.55], dual_err = [409.8, 396.8]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [78.77, 11.79], dual_err = [363, 352.5]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [67.12, 9.3], dual_err = [323.6, 315]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [57.52, 7.601], dual_err = [290.1, 283.1]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [49.57, 6.389], dual_err = [261.6, 255.8]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [42.95, 5.484], dual_err = [237.1, 232.3]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [37.42, 4.782], dual_err = [215.9, 212]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [32.76, 4.221], dual_err = [197.6, 194.2]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [28.82, 3.762], dual_err = [181.6, 178.8]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [25.46, 3.38], dual_err = [167.6, 165.2]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [22.59, 3.058], dual_err = [155.3, 153.3]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [20.12, 2.783], dual_err = [144.4, 142.7]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [17.98, 2.547], dual_err = [134.8, 133.4]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [16.12, 2.342], dual_err = [126.3, 125]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [14.49, 2.164], dual_err = [118.7, 117.6]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [13.07, 2.007], dual_err = [111.9, 111]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [11.81, 1.869], dual_err = [105.9, 105.1]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [10.7, 1.746], dual_err = [100.4, 99.75]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [9.723, 1.637], dual_err = [95.54, 94.95]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.852, 1.539], dual_err = [91.12, 90.61]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.077, 1.451], dual_err = [87.12, 86.67]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [7.385, 1.372], dual_err = [83.48, 83.09]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.767, 1.3], dual_err = [80.17, 79.82]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.215, 1.235], dual_err = [77.13, 76.83]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.719, 1.176], dual_err = [74.35, 74.09]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.274, 1.122], dual_err = [71.79, 71.56]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.875, 1.072], dual_err = [69.43, 69.22]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.515, 1.026], dual_err = [67.24, 67.06]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.192, 0.9835], dual_err = [65.2, 65.04]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.9, 0.9443], dual_err = [63.31, 63.16]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.636, 0.9079], dual_err = [61.53, 61.41]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.397, 0.874], dual_err = [59.87, 59.76]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.181, 0.8423], dual_err = [58.31, 58.21]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.986, 0.8127], dual_err = [56.84, 56.75]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.808, 0.785], dual_err = [55.45, 55.36]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.646, 0.759], dual_err = [54.13, 54.05]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.498, 0.7344], dual_err = [52.88, 52.81]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.363, 0.7113], dual_err = [51.69, 51.63]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.24, 0.6895], dual_err = [50.56, 50.5]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.127, 0.6688], dual_err = [49.48, 49.43]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.023, 0.6493], dual_err = [48.45, 48.4]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.928, 0.6307], dual_err = [47.46, 47.42]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.839, 0.6131], dual_err = [46.52, 46.48]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.758, 0.5964], dual_err = [45.61, 45.57]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.682, 0.5804], dual_err = [44.74, 44.7]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.612, 0.5652], dual_err = [43.9, 43.87]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.547, 0.5507], dual_err = [43.09, 43.06]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.486, 0.5369], dual_err = [42.31, 42.28]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.429, 0.5237], dual_err = [41.56, 41.54]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.375, 0.511], dual_err = [40.84, 40.81]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.325, 0.4989], dual_err = [40.14, 40.11]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.278, 0.4873], dual_err = [39.46, 39.44]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.233, 0.4762], dual_err = [38.81, 38.79]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.191, 0.4655], dual_err = [38.18, 38.15]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.151, 0.4553], dual_err = [37.56, 37.54]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.114, 0.4454], dual_err = [36.97, 36.95]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.078, 0.436], dual_err = [36.39, 36.37]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.044, 0.4269], dual_err = [35.83, 35.81]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.012, 0.4181], dual_err = [35.29, 35.27]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9811, 0.4097], dual_err = [34.76, 34.75]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9518, 0.4016], dual_err = [34.25, 34.23]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9237, 0.3937], dual_err = [33.75, 33.74]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.897, 0.3862], dual_err = [33.27, 33.25]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8714, 0.3789], dual_err = [32.8, 32.78]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8468, 0.3719], dual_err = [32.34, 32.33]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8233, 0.3651], dual_err = [31.89, 31.88]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8007, 0.3585], dual_err = [31.46, 31.45]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.779, 0.3522], dual_err = [31.03, 31.02]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7582, 0.346], dual_err = [30.62, 30.61]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7382, 0.3401], dual_err = [30.22, 30.21]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7189, 0.3343], dual_err = [29.83, 29.82]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7004, 0.3287], dual_err = [29.44, 29.44]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6825, 0.3233], dual_err = [29.07, 29.06]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6653, 0.3181], dual_err = [28.71, 28.7]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6487, 0.313], dual_err = [28.35, 28.34]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6327, 0.3081], dual_err = [28, 28]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6172, 0.3033], dual_err = [27.66, 27.66]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6023, 0.2987], dual_err = [27.33, 27.33]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5878, 0.2942], dual_err = [27.01, 27]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5739, 0.2898], dual_err = [26.69, 26.68]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5604, 0.2855], dual_err = [26.38, 26.37]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5474, 0.2814], dual_err = [26.08, 26.07]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5348, 0.2774], dual_err = [25.78, 25.77]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5226, 0.2734], dual_err = [25.49, 25.48]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5108, 0.2696], dual_err = [25.21, 25.2]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4993, 0.2659], dual_err = [24.93, 24.92]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4883, 0.2623], dual_err = [24.65, 24.65]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4775, 0.2588], dual_err = [24.39, 24.38]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4671, 0.2553], dual_err = [24.12, 24.12]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.457, 0.252], dual_err = [23.87, 23.86]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4473, 0.2487], dual_err = [23.62, 23.61]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4378, 0.2455], dual_err = [23.37, 23.36]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4286, 0.2424], dual_err = [23.13, 23.12]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %% [markdown]
# ### 3.3.2 w/o DGTV
# Remove DGTV term for kNN graph and line graph

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=True,
                            ablation='DGTV'
                            )
x_interp = admm_block.combined_loop(interp_y, mask=mask)
admm_block.plot_residual(descriptions='Interpolation, Line Graph, w/o DGTV', log_y=True)
admm_block.plot_x_per_step(descriptions='Interpolation, Line Graph, w/o DGTV', log_y=False)
admm_block.plot_x_per_step(descriptions='Interpolation, Line Graph, w/o DGTV', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 1])
# Linear regression: w torch.Size([1, 307, 1]), b torch.Size([1, 307, 1])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1186, 573.2], dual_err = [1187, 573.2]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [92.63, 72.16], dual_err = [418, 1336]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [131.2, 92.99], dual_err = [504, 554]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [111.7, 90.53], dual_err = [430, 414.4]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [89.68, 72.53], dual_err = [355.8, 341.5]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [72.11, 54.53], dual_err = [297.6, 286.5]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [58.47, 40.82], dual_err = [251.8, 243.1]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [47.84, 31.39], dual_err = [215.2, 208.2]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [39.47, 25.07], dual_err = [185.5, 179.9]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [32.84, 20.7], dual_err = [161, 156.6]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [27.53, 17.5], dual_err = [140.7, 137.1]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [23.25, 15.01], dual_err = [123.6, 120.8]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [19.77, 13], dual_err = [109.2, 106.9]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [16.92, 11.33], dual_err = [96.85, 94.99]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [14.56, 9.928], dual_err = [86.27, 84.75]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [12.6, 8.735], dual_err = [77.14, 75.89]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [10.95, 7.716], dual_err = [69.22, 68.18]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [9.564, 6.841], dual_err = [62.31, 61.45]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [8.382, 6.088], dual_err = [56.26, 55.54]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [7.371, 5.436], dual_err = [50.95, 50.34]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.503, 4.871], dual_err = [46.26, 45.74]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.753, 4.379], dual_err = [42.11, 41.67]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.102, 3.949], dual_err = [38.43, 38.06]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.537, 3.573], dual_err = [35.15, 34.84]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.043, 3.241], dual_err = [32.23, 31.96]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.61, 2.949], dual_err = [29.61, 29.39]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.23, 2.691], dual_err = [27.27, 27.08]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.896, 2.461], dual_err = [25.16, 25]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.602, 2.257], dual_err = [23.27, 23.13]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.342, 2.075], dual_err = [21.55, 21.43]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.111, 1.912], dual_err = [20, 19.9]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.907, 1.765], dual_err = [18.6, 18.51]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.726, 1.633], dual_err = [17.32, 17.24]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.565, 1.514], dual_err = [16.15, 16.09]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.421, 1.407], dual_err = [15.09, 15.04]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.293, 1.309], dual_err = [14.12, 14.07]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.179, 1.22], dual_err = [13.23, 13.19]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.077, 1.139], dual_err = [12.41, 12.38]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.985, 1.065], dual_err = [11.66, 11.63]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9029, 0.9968], dual_err = [10.97, 10.94]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8292, 0.9346], dual_err = [10.33, 10.3]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7628, 0.8773], dual_err = [9.733, 9.716]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7031, 0.8245], dual_err = [9.185, 9.169]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6492, 0.7758], dual_err = [8.675, 8.662]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6004, 0.7307], dual_err = [8.202, 8.191]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5563, 0.689], dual_err = [7.761, 7.752]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5163, 0.6502], dual_err = [7.35, 7.342]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.48, 0.6142], dual_err = [6.966, 6.96]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.447, 0.5807], dual_err = [6.608, 6.602]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4168, 0.5495], dual_err = [6.272, 6.268]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3893, 0.5203], dual_err = [5.958, 5.954]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3642, 0.4931], dual_err = [5.663, 5.66]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3411, 0.4676], dual_err = [5.386, 5.383]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3199, 0.4437], dual_err = [5.126, 5.123]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3004, 0.4213], dual_err = [4.881, 4.879]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2825, 0.4003], dual_err = [4.65, 4.649]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2659, 0.3806], dual_err = [4.433, 4.431]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2506, 0.362], dual_err = [4.227, 4.226]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2365, 0.3446], dual_err = [4.034, 4.033]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2233, 0.3281], dual_err = [3.851, 3.85]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2111, 0.3126], dual_err = [3.678, 3.677]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1997, 0.298], dual_err = [3.514, 3.514]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1891, 0.2842], dual_err = [3.359, 3.359]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1793, 0.2711], dual_err = [3.212, 3.212]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.17, 0.2588], dual_err = [3.072, 3.072]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1614, 0.2471], dual_err = [2.94, 2.94]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1533, 0.2361], dual_err = [2.815, 2.815]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1457, 0.2256], dual_err = [2.696, 2.696]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1386, 0.2157], dual_err = [2.582, 2.583]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1319, 0.2063], dual_err = [2.475, 2.475]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1256, 0.1974], dual_err = [2.372, 2.373]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1197, 0.1889], dual_err = [2.275, 2.275]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1141, 0.1809], dual_err = [2.182, 2.183]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1088, 0.1733], dual_err = [2.094, 2.094]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1038, 0.166], dual_err = [2.01, 2.01]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09914, 0.1591], dual_err = [1.929, 1.93]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09468, 0.1525], dual_err = [1.853, 1.853]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.09047, 0.1463], dual_err = [1.78, 1.78]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08648, 0.1403], dual_err = [1.71, 1.711]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08269, 0.1347], dual_err = [1.644, 1.644]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07911, 0.1293], dual_err = [1.58, 1.58]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0757, 0.1241], dual_err = [1.519, 1.52]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07247, 0.1192], dual_err = [1.461, 1.462]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0694, 0.1145], dual_err = [1.406, 1.406]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06647, 0.1101], dual_err = [1.353, 1.353]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0637, 0.1058], dual_err = [1.302, 1.303]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06105, 0.1017], dual_err = [1.254, 1.254]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05854, 0.09782], dual_err = [1.207, 1.207]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05614, 0.0941], dual_err = [1.163, 1.163]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05386, 0.09054], dual_err = [1.12, 1.12]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05168, 0.08714], dual_err = [1.079, 1.079]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0496, 0.08389], dual_err = [1.04, 1.04]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04762, 0.08077], dual_err = [1.003, 1.003]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04573, 0.07779], dual_err = [0.9666, 0.9669]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04393, 0.07494], dual_err = [0.9321, 0.9323]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0422, 0.07221], dual_err = [0.899, 0.8992]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04056, 0.06959], dual_err = [0.8672, 0.8675]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03898, 0.06708], dual_err = [0.8368, 0.837]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03748, 0.06467], dual_err = [0.8075, 0.8077]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03604, 0.06237], dual_err = [0.7794, 0.7796]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=False,
                            ablation='DGTV'
                            )
x_interp = admm_block.combined_loop(interp_y, mask=mask)
admm_block.plot_residual(descriptions='Interpolation, kNN, w/o DGTV', log_y=True)
admm_block.plot_x_per_step(descriptions='Interpolation, kNN, w/o DGTV', log_y=False)
admm_block.plot_x_per_step(descriptions='Interpolation, kNN, w/o DGTV', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# Directed Graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 5])
# Linear regression: w torch.Size([1, 307, 1]), b torch.Size([1, 307, 1])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1186, 573.8], dual_err = [1187, 573.8]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [94.81, 74.95], dual_err = [422.5, 1325]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [131.4, 91.79], dual_err = [504.7, 555.1]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [111.8, 89.27], dual_err = [430.3, 415.4]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [89.67, 71.68], dual_err = [355.9, 341.8]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [72.01, 54.07], dual_err = [297.5, 286.6]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [58.33, 40.61], dual_err = [251.6, 243]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [47.68, 31.32], dual_err = [215, 208.1]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [39.32, 25.06], dual_err = [185.3, 179.8]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [32.69, 20.71], dual_err = [160.8, 156.5]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [27.4, 17.5], dual_err = [140.5, 137]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [23.14, 15.02], dual_err = [123.5, 120.7]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [19.68, 13], dual_err = [109.1, 106.8]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [16.85, 11.33], dual_err = [96.77, 94.94]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [14.5, 9.921], dual_err = [86.22, 84.72]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [12.55, 8.726], dual_err = [77.11, 75.88]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 15, pri_err = [10.92, 7.707], dual_err = [69.2, 68.18]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [9.535, 6.832], dual_err = [62.3, 61.45]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [8.359, 6.078], dual_err = [56.26, 55.55]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [7.354, 5.427], dual_err = [50.95, 50.35]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [6.489, 4.862], dual_err = [46.27, 45.76]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.742, 4.371], dual_err = [42.12, 41.69]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [5.094, 3.941], dual_err = [38.44, 38.07]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.53, 3.565], dual_err = [35.16, 34.85]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [4.038, 3.234], dual_err = [32.24, 31.98]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.607, 2.943], dual_err = [29.63, 29.4]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [3.228, 2.684], dual_err = [27.29, 27.09]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.894, 2.455], dual_err = [25.18, 25.02]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.6, 2.251], dual_err = [23.28, 23.14]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.341, 2.069], dual_err = [21.57, 21.45]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [2.111, 1.907], dual_err = [20.02, 19.91]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.907, 1.76], dual_err = [18.61, 18.52]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.726, 1.629], dual_err = [17.33, 17.26]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.565, 1.51], dual_err = [16.17, 16.1]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [1.421, 1.402], dual_err = [15.1, 15.05]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.293, 1.305], dual_err = [14.13, 14.08]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 14, pri_err = [1.179, 1.216], dual_err = [13.24, 13.2]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.077, 1.135], dual_err = [12.42, 12.39]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9851, 1.061], dual_err = [11.67, 11.64]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.903, 0.9934], dual_err = [10.97, 10.95]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8292, 0.9313], dual_err = [10.33, 10.31]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7628, 0.8742], dual_err = [9.739, 9.722]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.703, 0.8215], dual_err = [9.19, 9.175]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6491, 0.773], dual_err = [8.68, 8.667]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.6003, 0.728], dual_err = [8.206, 8.195]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5562, 0.6864], dual_err = [7.765, 7.755]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.5161, 0.6478], dual_err = [7.353, 7.345]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4797, 0.6119], dual_err = [6.969, 6.963]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4466, 0.5785], dual_err = [6.61, 6.605]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.4165, 0.5473], dual_err = [6.274, 6.269]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3889, 0.5183], dual_err = [5.959, 5.955]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3637, 0.4911], dual_err = [5.664, 5.661]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3406, 0.4657], dual_err = [5.387, 5.384]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.3194, 0.4419], dual_err = [5.126, 5.124]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2999, 0.4196], dual_err = [4.881, 4.879]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2819, 0.3987], dual_err = [4.65, 4.648]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2653, 0.379], dual_err = [4.432, 4.431]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.25, 0.3605], dual_err = [4.227, 4.226]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2358, 0.3431], dual_err = [4.033, 4.032]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2226, 0.3267], dual_err = [3.849, 3.849]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.2104, 0.3113], dual_err = [3.676, 3.676]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.199, 0.2967], dual_err = [3.512, 3.512]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1884, 0.283], dual_err = [3.357, 3.357]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1785, 0.27], dual_err = [3.21, 3.21]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1693, 0.2577], dual_err = [3.07, 3.07]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1607, 0.246], dual_err = [2.938, 2.938]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.1526, 0.235], dual_err = [2.812, 2.812]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.145, 0.2246], dual_err = [2.693, 2.693]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1379, 0.2147], dual_err = [2.58, 2.58]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1312, 0.2054], dual_err = [2.472, 2.472]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1249, 0.1965], dual_err = [2.369, 2.37]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1189, 0.1881], dual_err = [2.272, 2.272]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1134, 0.1801], dual_err = [2.179, 2.179]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1081, 0.1725], dual_err = [2.091, 2.091]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.1031, 0.1652], dual_err = [2.007, 2.007]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09841, 0.1584], dual_err = [1.926, 1.927]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 12, pri_err = [0.09396, 0.1518], dual_err = [1.85, 1.85]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08976, 0.1456], dual_err = [1.777, 1.777]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.08577, 0.1397], dual_err = [1.707, 1.707]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.082, 0.134], dual_err = [1.64, 1.641]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07842, 0.1286], dual_err = [1.577, 1.577]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07503, 0.1235], dual_err = [1.516, 1.517]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.07181, 0.1186], dual_err = [1.458, 1.459]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06874, 0.114], dual_err = [1.403, 1.403]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06584, 0.1095], dual_err = [1.35, 1.35]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06307, 0.1053], dual_err = [1.299, 1.299]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.06044, 0.1012], dual_err = [1.251, 1.251]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05794, 0.09733], dual_err = [1.204, 1.204]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05555, 0.09362], dual_err = [1.16, 1.16]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05328, 0.09008], dual_err = [1.117, 1.117]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.05112, 0.08669], dual_err = [1.076, 1.077]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04905, 0.08345], dual_err = [1.037, 1.038]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04709, 0.08035], dual_err = [0.9997, 1]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04521, 0.07739], dual_err = [0.9638, 0.9641]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04342, 0.07455], dual_err = [0.9294, 0.9296]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.0417, 0.07182], dual_err = [0.8963, 0.8966]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.04007, 0.06922], dual_err = [0.8646, 0.8649]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03851, 0.06672], dual_err = [0.8342, 0.8345]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03702, 0.06433], dual_err = [0.805, 0.8052]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 12, pri_err = [0.03559, 0.06203], dual_err = [0.777, 0.7772]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=True,
                            ablation='DGTV'
                            )
x_pred = admm_block.combined_loop(y)
admm_block.plot_residual(descriptions='Prediction, Line Graph, w/o DGTV', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, Line Graph, w/o DGTV', log_y=False)
admm_block.plot_x_per_step(descriptions='Prediction, Line Graph, w/o DGTV', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 1])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1696, 345.9], dual_err = [1696, 345.9]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [80.61, 38.72], dual_err = [339.9, 1985]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [206.2, 49.86], dual_err = [768.9, 893.1]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [187.6, 48.68], dual_err = [707, 691.4]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [157.8, 38.45], dual_err = [614.2, 590.4]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [132, 28.03], dual_err = [533.7, 513.5]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [110.8, 20], dual_err = [466.7, 450.3]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [93.52, 14.48], dual_err = [410.9, 397.6]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [79.32, 10.89], dual_err = [364.1, 353.3]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [67.64, 8.575], dual_err = [324.5, 315.8]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [58, 7.047], dual_err = [291, 283.8]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [49.99, 5.98], dual_err = [262.3, 256.4]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [43.32, 5.188], dual_err = [237.7, 232.8]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [37.73, 4.571], dual_err = [216.4, 212.4]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [33.02, 4.071], dual_err = [198, 194.6]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [29.04, 3.656], dual_err = [181.9, 179.1]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [25.64, 3.306], dual_err = [167.8, 165.4]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [22.74, 3.006], dual_err = [155.5, 153.5]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [20.24, 2.747], dual_err = [144.6, 142.9]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [18.08, 2.521], dual_err = [134.9, 133.5]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [16.2, 2.324], dual_err = [126.4, 125.1]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [14.56, 2.151], dual_err = [118.8, 117.7]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [13.12, 1.997], dual_err = [112, 111.1]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [11.85, 1.861], dual_err = [105.9, 105.1]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [10.74, 1.74], dual_err = [100.5, 99.79]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [9.752, 1.632], dual_err = [95.57, 94.97]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.875, 1.535], dual_err = [91.14, 90.62]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.096, 1.448], dual_err = [87.13, 86.68]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [7.401, 1.369], dual_err = [83.49, 83.1]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.781, 1.298], dual_err = [80.17, 79.82]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.226, 1.233], dual_err = [77.13, 76.83]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.729, 1.174], dual_err = [74.35, 74.08]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.283, 1.12], dual_err = [71.78, 71.55]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.882, 1.07], dual_err = [69.41, 69.21]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.522, 1.024], dual_err = [67.22, 67.04]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.197, 0.9819], dual_err = [65.19, 65.02]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.905, 0.9428], dual_err = [63.29, 63.14]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.64, 0.9064], dual_err = [61.51, 61.38]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.401, 0.8726], dual_err = [59.85, 59.73]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.185, 0.841], dual_err = [58.28, 58.18]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.989, 0.8114], dual_err = [56.81, 56.72]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.811, 0.7837], dual_err = [55.42, 55.33]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.649, 0.7577], dual_err = [54.1, 54.02]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.501, 0.7332], dual_err = [52.85, 52.78]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.366, 0.7102], dual_err = [51.66, 51.6]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.242, 0.6884], dual_err = [50.53, 50.47]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.129, 0.6677], dual_err = [49.45, 49.39]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.025, 0.6482], dual_err = [48.41, 48.36]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.929, 0.6297], dual_err = [47.43, 47.38]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.841, 0.6121], dual_err = [46.48, 46.44]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.759, 0.5953], dual_err = [45.57, 45.53]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.684, 0.5794], dual_err = [44.7, 44.66]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.613, 0.5642], dual_err = [43.86, 43.82]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.548, 0.5498], dual_err = [43.05, 43.02]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.487, 0.5359], dual_err = [42.27, 42.24]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.43, 0.5227], dual_err = [41.52, 41.49]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.376, 0.5101], dual_err = [40.8, 40.77]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.326, 0.498], dual_err = [40.1, 40.07]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.279, 0.4864], dual_err = [39.42, 39.39]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.234, 0.4753], dual_err = [38.76, 38.74]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.192, 0.4646], dual_err = [38.13, 38.11]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.152, 0.4544], dual_err = [37.52, 37.5]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.115, 0.4446], dual_err = [36.92, 36.9]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.079, 0.4351], dual_err = [36.34, 36.33]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.045, 0.426], dual_err = [35.78, 35.77]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.013, 0.4173], dual_err = [35.24, 35.22]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.9818, 0.4088], dual_err = [34.71, 34.7]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.9524, 0.4007], dual_err = [34.2, 34.18]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.9244, 0.3929], dual_err = [33.7, 33.69]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8976, 0.3853], dual_err = [33.22, 33.2]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.872, 0.3781], dual_err = [32.75, 32.73]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8474, 0.371], dual_err = [32.29, 32.27]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8239, 0.3642], dual_err = [31.84, 31.83]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.8013, 0.3577], dual_err = [31.41, 31.39]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7796, 0.3513], dual_err = [30.98, 30.97]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7587, 0.3452], dual_err = [30.57, 30.56]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7387, 0.3392], dual_err = [30.17, 30.16]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7194, 0.3335], dual_err = [29.77, 29.76]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7009, 0.3279], dual_err = [29.39, 29.38]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.683, 0.3225], dual_err = [29.02, 29.01]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6657, 0.3173], dual_err = [28.65, 28.64]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6491, 0.3122], dual_err = [28.3, 28.29]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6331, 0.3073], dual_err = [27.95, 27.94]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6176, 0.3025], dual_err = [27.61, 27.6]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6027, 0.2978], dual_err = [27.28, 27.27]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5882, 0.2933], dual_err = [26.95, 26.95]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5743, 0.2889], dual_err = [26.64, 26.63]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5608, 0.2847], dual_err = [26.33, 26.32]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5478, 0.2805], dual_err = [26.02, 26.02]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5351, 0.2765], dual_err = [25.72, 25.72]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5229, 0.2726], dual_err = [25.43, 25.43]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.5111, 0.2688], dual_err = [25.15, 25.14]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4997, 0.2651], dual_err = [24.87, 24.86]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4886, 0.2614], dual_err = [24.6, 24.59]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4779, 0.2579], dual_err = [24.33, 24.32]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4674, 0.2545], dual_err = [24.07, 24.06]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4574, 0.2511], dual_err = [23.81, 23.8]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4476, 0.2479], dual_err = [23.56, 23.55]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4381, 0.2447], dual_err = [23.31, 23.31]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 7, zd_CG_iters 13, pri_err = [0.4289, 0.2416], dual_err = [23.07, 23.06]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 2,
    'mu_u': mu_init,
    'mu_d1':mu_init * 2,
    'mu_d2': mu_init
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=False,
                            ablation='DGTV'
                            )
x_pred = admm_block.combined_loop(y)
admm_block.plot_residual(descriptions='Prediction, kNN, w/o DGTV', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, kNN, w/o DGTV', log_y=False)
admm_block.plot_x_per_step(descriptions='Prediction, kNN, w/o DGTV', log_y=True)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# Directed Graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([24, 307, 4]) torch.Size([23, 307, 5])
# ADMM iters 0: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [1696, 371.1], dual_err = [1696, 371.1]
# ADMM iters 1: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [89.95, 51.7], dual_err = [361.2, 1970]
# ADMM iters 2: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [207.3, 53.39], dual_err = [771.6, 894.9]
# ADMM iters 3: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 16, pri_err = [187.7, 50.48], dual_err = [707.6, 692.6]
# ADMM iters 4: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [157.7, 39.88], dual_err = [613.9, 590.6]
# ADMM iters 5: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [131.7, 29.34], dual_err = [532.9, 513.1]
# ADMM iters 6: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [110.3, 21.21], dual_err = [465.7, 449.6]
# ADMM iters 7: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [92.96, 15.55], dual_err = [409.8, 396.8]
# ADMM iters 8: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [78.77, 11.79], dual_err = [363, 352.5]
# ADMM iters 9: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [67.12, 9.3], dual_err = [323.6, 315]
# ADMM iters 10: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 15, pri_err = [57.52, 7.601], dual_err = [290.1, 283.1]
# ADMM iters 11: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [49.57, 6.389], dual_err = [261.6, 255.8]
# ADMM iters 12: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [42.95, 5.484], dual_err = [237.1, 232.3]
# ADMM iters 13: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [37.42, 4.782], dual_err = [215.9, 212]
# ADMM iters 14: x_CG_iters 2, zu_CG_iters 11, zd_CG_iters 14, pri_err = [32.76, 4.221], dual_err = [197.6, 194.2]
# ADMM iters 15: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [28.82, 3.762], dual_err = [181.6, 178.8]
# ADMM iters 16: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [25.46, 3.38], dual_err = [167.6, 165.2]
# ADMM iters 17: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [22.59, 3.058], dual_err = [155.3, 153.3]
# ADMM iters 18: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [20.12, 2.783], dual_err = [144.4, 142.7]
# ADMM iters 19: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [17.98, 2.547], dual_err = [134.8, 133.4]
# ADMM iters 20: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [16.12, 2.342], dual_err = [126.3, 125]
# ADMM iters 21: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [14.49, 2.164], dual_err = [118.7, 117.6]
# ADMM iters 22: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 14, pri_err = [13.07, 2.007], dual_err = [111.9, 111]
# ADMM iters 23: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [11.81, 1.869], dual_err = [105.9, 105.1]
# ADMM iters 24: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [10.7, 1.746], dual_err = [100.4, 99.75]
# ADMM iters 25: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [9.723, 1.637], dual_err = [95.54, 94.95]
# ADMM iters 26: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.852, 1.539], dual_err = [91.12, 90.61]
# ADMM iters 27: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [8.077, 1.451], dual_err = [87.12, 86.67]
# ADMM iters 28: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [7.385, 1.372], dual_err = [83.48, 83.09]
# ADMM iters 29: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.767, 1.3], dual_err = [80.17, 79.82]
# ADMM iters 30: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [6.215, 1.235], dual_err = [77.13, 76.83]
# ADMM iters 31: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.719, 1.176], dual_err = [74.35, 74.09]
# ADMM iters 32: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [5.274, 1.122], dual_err = [71.79, 71.56]
# ADMM iters 33: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.875, 1.072], dual_err = [69.43, 69.22]
# ADMM iters 34: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.515, 1.026], dual_err = [67.24, 67.06]
# ADMM iters 35: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [4.192, 0.9835], dual_err = [65.2, 65.04]
# ADMM iters 36: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.9, 0.9443], dual_err = [63.31, 63.16]
# ADMM iters 37: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.636, 0.9079], dual_err = [61.53, 61.41]
# ADMM iters 38: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.397, 0.874], dual_err = [59.87, 59.76]
# ADMM iters 39: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [3.181, 0.8423], dual_err = [58.31, 58.21]
# ADMM iters 40: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.986, 0.8127], dual_err = [56.84, 56.75]
# ADMM iters 41: x_CG_iters 2, zu_CG_iters 10, zd_CG_iters 13, pri_err = [2.808, 0.785], dual_err = [55.45, 55.36]
# ADMM iters 42: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.646, 0.759], dual_err = [54.13, 54.05]
# ADMM iters 43: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.498, 0.7344], dual_err = [52.88, 52.81]
# ADMM iters 44: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.363, 0.7113], dual_err = [51.69, 51.63]
# ADMM iters 45: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.24, 0.6895], dual_err = [50.56, 50.5]
# ADMM iters 46: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.127, 0.6688], dual_err = [49.48, 49.43]
# ADMM iters 47: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [2.023, 0.6493], dual_err = [48.45, 48.4]
# ADMM iters 48: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.928, 0.6307], dual_err = [47.46, 47.42]
# ADMM iters 49: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.839, 0.6131], dual_err = [46.52, 46.48]
# ADMM iters 50: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.758, 0.5964], dual_err = [45.61, 45.57]
# ADMM iters 51: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.682, 0.5804], dual_err = [44.74, 44.7]
# ADMM iters 52: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.612, 0.5652], dual_err = [43.9, 43.87]
# ADMM iters 53: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.547, 0.5507], dual_err = [43.09, 43.06]
# ADMM iters 54: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.486, 0.5369], dual_err = [42.31, 42.28]
# ADMM iters 55: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.429, 0.5237], dual_err = [41.56, 41.54]
# ADMM iters 56: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.375, 0.511], dual_err = [40.84, 40.81]
# ADMM iters 57: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.325, 0.4989], dual_err = [40.14, 40.11]
# ADMM iters 58: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.278, 0.4873], dual_err = [39.46, 39.44]
# ADMM iters 59: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.233, 0.4762], dual_err = [38.81, 38.79]
# ADMM iters 60: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.191, 0.4655], dual_err = [38.18, 38.15]
# ADMM iters 61: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.151, 0.4553], dual_err = [37.56, 37.54]
# ADMM iters 62: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.114, 0.4454], dual_err = [36.97, 36.95]
# ADMM iters 63: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.078, 0.436], dual_err = [36.39, 36.37]
# ADMM iters 64: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.044, 0.4269], dual_err = [35.83, 35.81]
# ADMM iters 65: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [1.012, 0.4181], dual_err = [35.29, 35.27]
# ADMM iters 66: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9811, 0.4097], dual_err = [34.76, 34.75]
# ADMM iters 67: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9518, 0.4016], dual_err = [34.25, 34.23]
# ADMM iters 68: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.9237, 0.3937], dual_err = [33.75, 33.74]
# ADMM iters 69: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.897, 0.3862], dual_err = [33.27, 33.25]
# ADMM iters 70: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8714, 0.3789], dual_err = [32.8, 32.78]
# ADMM iters 71: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8468, 0.3719], dual_err = [32.34, 32.33]
# ADMM iters 72: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8233, 0.3651], dual_err = [31.89, 31.88]
# ADMM iters 73: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.8007, 0.3585], dual_err = [31.46, 31.45]
# ADMM iters 74: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.779, 0.3522], dual_err = [31.03, 31.02]
# ADMM iters 75: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7582, 0.346], dual_err = [30.62, 30.61]
# ADMM iters 76: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7382, 0.3401], dual_err = [30.22, 30.21]
# ADMM iters 77: x_CG_iters 2, zu_CG_iters 9, zd_CG_iters 13, pri_err = [0.7189, 0.3343], dual_err = [29.83, 29.82]
# ADMM iters 78: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.7004, 0.3287], dual_err = [29.44, 29.44]
# ADMM iters 79: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6825, 0.3233], dual_err = [29.07, 29.06]
# ADMM iters 80: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6653, 0.3181], dual_err = [28.71, 28.7]
# ADMM iters 81: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6487, 0.313], dual_err = [28.35, 28.34]
# ADMM iters 82: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6327, 0.3081], dual_err = [28, 28]
# ADMM iters 83: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6172, 0.3033], dual_err = [27.66, 27.66]
# ADMM iters 84: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.6023, 0.2987], dual_err = [27.33, 27.33]
# ADMM iters 85: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5878, 0.2942], dual_err = [27.01, 27]
# ADMM iters 86: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5739, 0.2898], dual_err = [26.69, 26.68]
# ADMM iters 87: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5604, 0.2855], dual_err = [26.38, 26.37]
# ADMM iters 88: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5474, 0.2814], dual_err = [26.08, 26.07]
# ADMM iters 89: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5348, 0.2774], dual_err = [25.78, 25.77]
# ADMM iters 90: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5226, 0.2734], dual_err = [25.49, 25.48]
# ADMM iters 91: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.5108, 0.2696], dual_err = [25.21, 25.2]
# ADMM iters 92: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4993, 0.2659], dual_err = [24.93, 24.92]
# ADMM iters 93: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4883, 0.2623], dual_err = [24.65, 24.65]
# ADMM iters 94: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4775, 0.2588], dual_err = [24.39, 24.38]
# ADMM iters 95: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4671, 0.2553], dual_err = [24.12, 24.12]
# ADMM iters 96: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.457, 0.252], dual_err = [23.87, 23.86]
# ADMM iters 97: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4473, 0.2487], dual_err = [23.62, 23.61]
# ADMM iters 98: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4378, 0.2455], dual_err = [23.37, 23.36]
# ADMM iters 99: x_CG_iters 2, zu_CG_iters 8, zd_CG_iters 13, pri_err = [0.4286, 0.2424], dual_err = [23.13, 23.12]
# torch.Size([100, 2]) torch.Size([100, 2]) torch.Size([100, 1])

# %%
import math
rho_init = math.sqrt(traffic_dataset.graph_info['n_nodes'] / 24)
mu_init = 1
print('rho_init:', rho_init)
ADMM_info = {
    'rho': rho_init * 2,
    'rho_u': rho_init * 3,
    'rho_d': rho_init * 0.5,
    'mu_u': mu_init,
    'mu_d1':mu_init * 20,
    'mu_d2': mu_init * 20
}
admm_block = ADMM_algorithm(traffic_dataset.graph_info,
                            ADMM_info,
                            use_kNN=True,
                            k=4,
                            u_sigma=50,
                            d_sigma=50,
                            use_line_graph=True,
                            t_in=11,
                            T=23
                            )
diff_x_pred = admm_block.combined_loop(diff_y)
admm_block.plot_residual(descriptions='Prediction, line, diff', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, line, diff', log_y=False)
admm_block.plot_x_per_step(descriptions='Prediction, line, diff', log_y=True)
admm_block.plot_x_per_step(descriptions='Prediction, line, diff', log_y=True, show_list=range(12, 23), start_iters=20)
admm_block.plot_x_per_step(descriptions='Prediction, line, diff', log_y=True, show_list=range(11), start_iters=20)
# Out:
# rho_init: 3.5765439556458225
# 307 nodes, 4 neighbors
# Undirected graph: sigma = 50, nearest_dist in (3.2000, 2895.6001)
# u_ew, d_ew shape torch.Size([23, 307, 4]) torch.Size([22, 307, 1])
# ADMM iters 0: x_CG_iters 16, zu_CG_iters 10, zd_CG_iters 23, pri_err = [290.6, 166.5, 1286], dual_err = [290.7, 166.5, 1286]
# ADMM iters 1: x_CG_iters 22, zu_CG_iters 11, zd_CG_iters 23, pri_err = [48.18, 50.8, 894.3], dual_err = [242.3, 414.2, 269.2]
# ADMM iters 2: x_CG_iters 21, zu_CG_iters 11, zd_CG_iters 23, pri_err = [55.3, 35.33, 648.6], dual_err = [260.9, 350.5, 113.4]
# ADMM iters 3: x_CG_iters 21, zu_CG_iters 11, zd_CG_iters 23, pri_err = [50.71, 33.14, 431.5], dual_err = [246.5, 334.3, 95.69]
# ADMM iters 4: x_CG_iters 21, zu_CG_iters 11, zd_CG_iters 23, pri_err = [43.88, 38.45, 249.7], dual_err = [222, 312.2, 81.12]
# ADMM iters 5: x_CG_iters 21, zu_CG_iters 11, zd_CG_iters 23, pri_err = [36.96, 54.32, 132.8], dual_err = [192.9, 277.2, 68.74]
# ADMM iters 6: x_CG_iters 21, zu_CG_iters 11, zd_CG_iters 23, pri_err = [30.17, 91.94, 141.6], dual_err = [159.9, 213.9, 59.12]
# ADMM iters 7: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [21.69, 115.5, 188.3], dual_err = [116.7, 110.4, 51.65]
# ADMM iters 8: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [11.61, 41.74, 193.9], dual_err = [60.87, 119.7, 44.5]
# ADMM iters 9: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [10.05, 23.69, 211.8], dual_err = [54.42, 75.04, 38.18]
# ADMM iters 10: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [7.454, 16.85, 220.3], dual_err = [44.21, 48.21, 33.37]
# ADMM iters 11: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [5.337, 15.05, 219.3], dual_err = [35.84, 29.85, 29.47]
# ADMM iters 12: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [4.198, 13.82, 210], dual_err = [31.32, 22.05, 26.31]
# ADMM iters 13: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [4.028, 13.3, 193.8], dual_err = [30.45, 24.92, 23.75]
# ADMM iters 14: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [4.333, 12.71, 172.8], dual_err = [31.34, 32.26, 21.64]
# ADMM iters 15: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [4.736, 12.94, 148.8], dual_err = [32.3, 39, 19.88]
# ADMM iters 16: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [5.017, 13.16, 123.3], dual_err = [32.71, 43.64, 18.4]
# ADMM iters 17: x_CG_iters 20, zu_CG_iters 10, zd_CG_iters 23, pri_err = [5.093, 13.45, 97.92], dual_err = [32.38, 45.94, 17.13]
# ADMM iters 18: x_CG_iters 19, zu_CG_iters 10, zd_CG_iters 23, pri_err = [4.987, 14.73, 74.21], dual_err = [31.26, 45.44, 16.03]
# ADMM iters 19: x_CG_iters 19, zu_CG_iters 10, zd_CG_iters 23, pri_err = [4.718, 17.63, 53.84], dual_err = [29.14, 42.03, 15.06]
# ADMM iters 20: x_CG_iters 19, zu_CG_iters 10, zd_CG_iters 23, pri_err = [4.255, 18.9, 39.17], dual_err = [26.08, 36.21, 14.22]
# ADMM iters 21: x_CG_iters 19, zu_CG_iters 10, zd_CG_iters 23, pri_err = [3.719, 22.71, 32], dual_err = [22.66, 25.42, 13.47]
# ADMM iters 22: x_CG_iters 19, zu_CG_iters 10, zd_CG_iters 23, pri_err = [2.761, 22.75, 30.42], dual_err = [17.96, 13.49, 12.8]
# ADMM iters 23: x_CG_iters 19, zu_CG_iters 10, zd_CG_iters 23, pri_err = [1.727, 13.85, 29.78], dual_err = [14.66, 11.57, 12.14]
# ADMM iters 24: x_CG_iters 19, zu_CG_iters 9, zd_CG_iters 23, pri_err = [1.359, 9.21, 29.13], dual_err = [12.93, 8.059, 11.48]
# ADMM iters 25: x_CG_iters 19, zu_CG_iters 9, zd_CG_iters 23, pri_err = [1.074, 7.333, 28.06], dual_err = [11.72, 6.318, 10.88]
# ADMM iters 26: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.868, 6.536, 26.77], dual_err = [10.9, 5.333, 10.33]
# ADMM iters 27: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.749, 6.17, 25.41], dual_err = [10.26, 4.74, 9.822]
# ADMM iters 28: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.6822, 5.861, 24.07], dual_err = [9.714, 4.445, 9.347]
# ADMM iters 29: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.644, 5.606, 22.77], dual_err = [9.248, 4.238, 8.903]
# ADMM iters 30: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.612, 5.414, 21.52], dual_err = [8.814, 4.1, 8.486]
# ADMM iters 31: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.5853, 5.207, 20.33], dual_err = [8.406, 4.056, 8.091]
# ADMM iters 32: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.5647, 5.022, 19.15], dual_err = [8.029, 3.996, 7.715]
# ADMM iters 33: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.5473, 4.867, 18.01], dual_err = [7.668, 3.916, 7.354]
# ADMM iters 34: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.527, 4.684, 16.96], dual_err = [7.319, 3.839, 7.009]
# ADMM iters 35: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.5001, 4.532, 15.99], dual_err = [6.98, 3.707, 6.68]
# ADMM iters 36: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.4738, 4.391, 15.12], dual_err = [6.653, 3.564, 6.366]
# ADMM iters 37: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.4471, 4.253, 14.35], dual_err = [6.337, 3.378, 6.066]
# ADMM iters 38: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.4178, 4.12, 13.67], dual_err = [6.031, 3.191, 5.78]
# ADMM iters 39: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.3914, 4.004, 13.08], dual_err = [5.737, 2.942, 5.505]
# ADMM iters 40: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.3606, 3.901, 12.57], dual_err = [5.45, 2.709, 5.243]
# ADMM iters 41: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.3297, 3.787, 12.12], dual_err = [5.174, 2.488, 4.992]
# ADMM iters 42: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.3056, 3.695, 11.7], dual_err = [4.912, 2.268, 4.753]
# ADMM iters 43: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2851, 3.598, 11.3], dual_err = [4.662, 2.084, 4.523]
# ADMM iters 44: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2693, 3.496, 10.91], dual_err = [4.428, 1.941, 4.303]
# ADMM iters 45: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2553, 3.389, 10.52], dual_err = [4.209, 1.835, 4.093]
# ADMM iters 46: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2432, 3.287, 10.11], dual_err = [4.004, 1.752, 3.892]
# ADMM iters 47: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2355, 3.179, 9.697], dual_err = [3.812, 1.696, 3.699]
# ADMM iters 48: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2291, 3.066, 9.298], dual_err = [3.628, 1.672, 3.515]
# ADMM iters 49: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2244, 2.959, 8.921], dual_err = [3.454, 1.612, 3.339]
# ADMM iters 50: x_CG_iters 18, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2152, 2.871, 8.576], dual_err = [3.283, 1.53, 3.171]
# ADMM iters 51: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.2015, 2.782, 8.269], dual_err = [3.114, 1.453, 3.009]
# ADMM iters 52: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1895, 2.692, 7.997], dual_err = [2.952, 1.361, 2.855]
# ADMM iters 53: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.177, 2.609, 7.761], dual_err = [2.794, 1.257, 2.707]
# ADMM iters 54: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1638, 2.53, 7.548], dual_err = [2.642, 1.155, 2.566]
# ADMM iters 55: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1515, 2.454, 7.35], dual_err = [2.496, 1.066, 2.431]
# ADMM iters 56: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1417, 2.387, 7.152], dual_err = [2.357, 0.9788, 2.301]
# ADMM iters 57: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1337, 2.314, 6.965], dual_err = [2.226, 0.9205, 2.176]
# ADMM iters 58: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1272, 2.237, 6.786], dual_err = [2.103, 0.8548, 2.058]
# ADMM iters 59: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1212, 2.16, 6.613], dual_err = [1.988, 0.8061, 1.946]
# ADMM iters 60: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1155, 2.088, 6.437], dual_err = [1.881, 0.7626, 1.84]
# ADMM iters 61: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1108, 2.017, 6.261], dual_err = [1.781, 0.7202, 1.739]
# ADMM iters 62: x_CG_iters 17, zu_CG_iters 9, zd_CG_iters 23, pri_err = [0.1061, 1.944, 6.094], dual_err = [1.685, 0.6879, 1.645]
# ADMM iters 63: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.1014, 1.869, 5.938], dual_err = [1.594, 0.6728, 1.555]
# ADMM iters 64: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.09787, 1.796, 5.786], dual_err = [1.508, 0.6377, 1.469]
# ADMM iters 65: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.09322, 1.727, 5.638], dual_err = [1.425, 0.6195, 1.389]
# ADMM iters 66: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.08927, 1.658, 5.491], dual_err = [1.349, 0.6096, 1.312]
# ADMM iters 67: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.08615, 1.597, 5.342], dual_err = [1.278, 0.5844, 1.241]
# ADMM iters 68: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.08375, 1.538, 5.202], dual_err = [1.21, 0.5718, 1.173]
# ADMM iters 69: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.08119, 1.481, 5.072], dual_err = [1.145, 0.5519, 1.109]
# ADMM iters 70: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.07831, 1.422, 4.952], dual_err = [1.082, 0.5357, 1.048]
# ADMM iters 71: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.07481, 1.364, 4.839], dual_err = [1.023, 0.5132, 0.9909]
# ADMM iters 72: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.07192, 1.307, 4.733], dual_err = [0.968, 0.4797, 0.9367]
# ADMM iters 73: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.06822, 1.254, 4.635], dual_err = [0.9143, 0.4491, 0.8856]
# ADMM iters 74: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.06424, 1.203, 4.541], dual_err = [0.8628, 0.4219, 0.8376]
# ADMM iters 75: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.06047, 1.155, 4.448], dual_err = [0.8149, 0.3976, 0.7925]
# ADMM iters 76: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.05751, 1.108, 4.357], dual_err = [0.771, 0.3715, 0.7503]
# ADMM iters 77: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.05481, 1.064, 4.267], dual_err = [0.7302, 0.3509, 0.7108]
# ADMM iters 78: x_CG_iters 17, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.05237, 1.024, 4.178], dual_err = [0.6923, 0.3331, 0.6739]
# ADMM iters 79: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.05003, 0.9857, 4.092], dual_err = [0.6569, 0.3154, 0.6394]
# ADMM iters 80: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.04757, 0.9492, 4.008], dual_err = [0.6232, 0.3077, 0.6072]
# ADMM iters 81: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.04582, 0.9157, 3.925], dual_err = [0.5927, 0.2935, 0.5771]
# ADMM iters 82: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.04398, 0.8808, 3.846], dual_err = [0.5637, 0.2902, 0.549]
# ADMM iters 83: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.04275, 0.8487, 3.765], dual_err = [0.5374, 0.2848, 0.5227]
# ADMM iters 84: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.04204, 0.8195, 3.685], dual_err = [0.5137, 0.2789, 0.4981]
# ADMM iters 85: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.04157, 0.7922, 3.607], dual_err = [0.4917, 0.2727, 0.4751]
# ADMM iters 86: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.04072, 0.7654, 3.532], dual_err = [0.4704, 0.2655, 0.4536]
# ADMM iters 87: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.03958, 0.7403, 3.461], dual_err = [0.4497, 0.2563, 0.4335]
# ADMM iters 88: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.03838, 0.7156, 3.395], dual_err = [0.43, 0.2438, 0.4146]
# ADMM iters 89: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.03672, 0.6919, 3.331], dual_err = [0.4107, 0.2328, 0.397]
# ADMM iters 90: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.03477, 0.6718, 3.269], dual_err = [0.3927, 0.2163, 0.3803]
# ADMM iters 91: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.03284, 0.6512, 3.211], dual_err = [0.3752, 0.2015, 0.3648]
# ADMM iters 92: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.03091, 0.6287, 3.153], dual_err = [0.3585, 0.1966, 0.35]
# ADMM iters 93: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.02994, 0.6103, 3.093], dual_err = [0.3446, 0.1914, 0.3359]
# ADMM iters 94: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.02976, 0.5952, 3.03], dual_err = [0.3329, 0.1859, 0.3227]
# ADMM iters 95: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.02937, 0.5805, 2.97], dual_err = [0.3213, 0.184, 0.3102]
# ADMM iters 96: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.02875, 0.5657, 2.913], dual_err = [0.3098, 0.1805, 0.2984]
# ADMM iters 97: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.02789, 0.5516, 2.858], dual_err = [0.2983, 0.1765, 0.2873]
# ADMM iters 98: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.02698, 0.5362, 2.805], dual_err = [0.2872, 0.174, 0.2767]
# ADMM iters 99: x_CG_iters 16, zu_CG_iters 8, zd_CG_iters 23, pri_err = [0.02619, 0.5219, 2.754], dual_err = [0.2768, 0.1666, 0.2666]
# torch.Size([100, 3]) torch.Size([100, 3]) torch.Size([100, 1])
